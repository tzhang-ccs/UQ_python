# %%
from smt.sampling_methods import LHS
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm.notebook  import tqdm
from loguru import logger
import multiprocessing as mp
from netCDF4 import Dataset
import pandas as pd

# %% [markdown]
# # set parameter ranges

# %%
para_limits = np.array([
    [0.01,1.4],
    [1.02E20, 1.67e24]
]
)

para_default = [0.1,1.15e23]

num = 1000

base_path="/home/tzhang/wrf_solar/wsolar412_bnl/"
archive_path = "/S2/gscr2/tzhang/big_data/UQ/sampling/"
para_names = ['vdis','beta_con']

# %%
sampling = LHS(xlimits=para_limits)
x = sampling(num)
print(x.shape)
print(x[0,:])
# Out:
# (1000, 2)
# [1.18663500e+00 7.07303803e+23]

# %%
para_samples = []
for id, xx in enumerate(x):
    samp = {}
    for i,name in enumerate(para_names):
        samp[name] = xx[i]
    para_samples.append((id,samp))

# %%
para_samples[0]
# Out:
# (0, {'vdis': 1.1866349999999999, 'beta_con': 7.073038029999999e+23})

# %%
plt.plot(x[:, 0], x[:, 1], "o")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
def run_case(id,x):
    #create a case
    #print("cp -r "+base_path+"/runwrf "+base_path+"/case"+str(id))
    os.system("cp -r "+base_path+"/runwrf "+base_path+"/case"+str(id))
    os.chdir(base_path+"/case"+str(id))
    logger.add("case"+str(id)+".log")
    logger.info("case"+str(id)+": create a case")
    logger.info("case"+str(id)+": "+str(x))
    #os.system("touch a")
    
    # modify runwrf.sh
    logger.info("case"+str(id)+": modifiy runwrf.sh")
    os.system("sed -i 's/runwrf/case0/g' runwrf.sh")
    
    # modify namelist
    logger.info("case"+str(id)+": modifiy namelist")
    for key in x:
        replace_str = "sed -i '/^ "+key+"/c\ "+key+"="+str(x[key])+"' namelist.input"
        os.system(replace_str)
    
    # run model
    logger.info("case"+str(id)+": run model")
    time.sleep(30)
    #jid = os.popen("qsub runwrf.sh").read().split('.')[0]
    #print(jid)
    #while os.popen("qstat").read().find(jid) != -1:
    #    time.sleep(300)
        
    #archive case
    logger.info("case"+str(id)+": archive case")
    os.chdir(base_path)
    #print("mv case"+str(id)+" "+archive_path)
    os.system("mv case"+str(id)+" "+archive_path) 
    
    logger.info("case"+str(id)+": success!!!")
    logger.remove()
    
def run_case_wrapper(args):
    return run_case(*args)

# %%
pool = mp.Pool(10)
pool.map(run_case_wrapper,para_samples[:10])
# Out:
# 2021-02-17 15:03:24.226 | INFO     | __main__:run_case:7 - case0: create a case
# 2021-02-17 15:03:24.231 | INFO     | __main__:run_case:8 - case0: {'vdis': 1.1866349999999999, 'beta_con': 7.073038029999999e+23}
# 2021-02-17 15:03:24.232 | INFO     | __main__:run_case:12 - case0: modifiy runwrf.sh
# 2021-02-17 15:03:25.585 | INFO     | __main__:run_case:16 - case0: modifiy namelist
# 2021-02-17 15:03:28.341 | INFO     | __main__:run_case:22 - case0: run model
# 2021-02-17 15:03:58.374 | INFO     | __main__:run_case:30 - case0: archive case
# 2021-02-17 15:04:07.314 | INFO     | __main__:run_case:35 - case0: success!!!
# 2021-02-17 15:05:25.044 | INFO     | __main__:run_case:7 - case4: create a case
# 2021-02-17 15:05:25.047 | INFO     | __main__:run_case:8 - case4: {'vdis': 0.8516449999999999, 'beta_con': 2.28043077e+23}
# 2021-02-17 15:05:25.048 | INFO     | __main__:run_case:12 - case4: modifiy runwrf.sh
# 2021-02-17 15:05:25.827 | INFO     | __main__:run_case:16 - case4: modifiy namelist
# 2021-02-17 15:05:28.848 | INFO     | __main__:run_case:22 - case4: run model
# 2021-02-17 15:05:30.455 | INFO     | __main__:run_case:7 - case6: create a case
# 2021-02-17 15:05:30.459 | INFO     | __main__:run_case:8 - case6: {'vdis': 0.7849250000000001, 'beta_con': 1.341865043e+24}
# 2021-02-17 15:05:30.460 | INFO     | __main__:run_case:12 - case6: modifiy runwrf.sh
# 2021-02-17 15:05:31.530 | INFO     | __main__:run_case:16 - case6: modifiy namelist
# 2021-02-17 15:05:33.631 | INFO     | __main__:run_case:22 - case6: run model
# 2021-02-17 15:05:58.882 | INFO     | __main__:run_case:30 - case4: archive case
# 2021-02-17 15:06:03.666 | INFO     | __main__:run_case:30 - case6: archive case
# 2021-02-17 15:06:07.289 | INFO     | __main__:run_case:35 - case4: success!!!
# 2021-02-17 15:06:18.869 | INFO     | __main__:run_case:35 - case6: success!!!
# 2021-02-17 15:06:18.921 | INFO     | __main__:run_case:7 - case9: create a case
# 2021-02-17 15:06:18.925 | INFO     | __main__:run_case:8 - case9: {'vdis': 0.8349649999999998, 'beta_con': 1.14490013e+23}
# 2021-02-17 15:06:18.927 | INFO     | __main__:run_case:12 - case9: modifiy runwrf.sh
# 2021-02-17 15:06:19.029 | INFO     | __main__:run_case:16 - case9: modifiy namelist
# 2021-02-17 15:06:19.488 | INFO     | __main__:run_case:22 - case9: run model
# 2021-02-17 15:06:30.465 | INFO     | __main__:run_case:7 - case1: create a case
# 2021-02-17 15:06:30.468 | INFO     | __main__:run_case:8 - case1: {'vdis': 0.504145, 'beta_con': 9.911864629999997e+23}
# 2021-02-17 15:06:30.469 | INFO     | __main__:run_case:12 - case1: modifiy runwrf.sh
# 2021-02-17 15:06:30.630 | INFO     | __main__:run_case:16 - case1: modifiy namelist
# 2021-02-17 15:06:31.673 | INFO     | __main__:run_case:22 - case1: run model
# 2021-02-17 15:06:38.525 | INFO     | __main__:run_case:7 - case7: create a case
# 2021-02-17 15:06:38.531 | INFO     | __main__:run_case:8 - case7: {'vdis': 0.340125, 'beta_con': 2.4315520999999995e+22}
# 2021-02-17 15:06:38.533 | INFO     | __main__:run_case:12 - case7: modifiy runwrf.sh
# 2021-02-17 15:06:38.718 | INFO     | __main__:run_case:16 - case7: modifiy namelist
# 2021-02-17 15:06:40.092 | INFO     | __main__:run_case:22 - case7: run model
# 2021-02-17 15:06:40.965 | INFO     | __main__:run_case:7 - case2: create a case
# 2021-02-17 15:06:40.970 | INFO     | __main__:run_case:8 - case2: {'vdis': 0.743225, 'beta_con': 7.006242109999999e+23}
# 2021-02-17 15:06:40.972 | INFO     | __main__:run_case:12 - case2: modifiy runwrf.sh
# 2021-02-17 15:06:41.528 | INFO     | __main__:run_case:16 - case2: modifiy namelist
# 2021-02-17 15:06:42.845 | INFO     | __main__:run_case:22 - case2: run model
# 2021-02-17 15:06:42.886 | INFO     | __main__:run_case:7 - case3: create a case
# 2021-02-17 15:06:42.891 | INFO     | __main__:run_case:8 - case3: {'vdis': 1.101845, 'beta_con': 9.845068709999998e+23}
# 2021-02-17 15:06:42.893 | INFO     | __main__:run_case:12 - case3: modifiy runwrf.sh
# 2021-02-17 15:06:43.082 | INFO     | __main__:run_case:7 - case8: create a case
# 2021-02-17 15:06:43.085 | INFO     | __main__:run_case:8 - case8: {'vdis': 0.291475, 'beta_con': 1.1765451409999998e+24}
# 2021-02-17 15:06:43.087 | INFO     | __main__:run_case:12 - case8: modifiy runwrf.sh
# 2021-02-17 15:06:43.221 | INFO     | __main__:run_case:16 - case3: modifiy namelist
# 2021-02-17 15:06:43.374 | INFO     | __main__:run_case:16 - case8: modifiy namelist
# 2021-02-17 15:06:43.444 | INFO     | __main__:run_case:7 - case5: create a case
# 2021-02-17 15:06:43.447 | INFO     | __main__:run_case:8 - case5: {'vdis': 0.373485, 'beta_con': 1.453748209e+24}
# 2021-02-17 15:06:43.448 | INFO     | __main__:run_case:12 - case5: modifiy runwrf.sh
# 2021-02-17 15:06:43.607 | INFO     | __main__:run_case:16 - case5: modifiy namelist
# 2021-02-17 15:06:44.048 | INFO     | __main__:run_case:22 - case3: run model
# 2021-02-17 15:06:44.048 | INFO     | __main__:run_case:22 - case8: run model
# 2021-02-17 15:06:44.214 | INFO     | __main__:run_case:22 - case5: run model
# 2021-02-17 15:06:49.521 | INFO     | __main__:run_case:30 - case9: archive case
# 2021-02-17 15:06:58.055 | INFO     | __main__:run_case:35 - case9: success!!!
# 2021-02-17 15:07:01.707 | INFO     | __main__:run_case:30 - case1: archive case
# 2021-02-17 15:07:10.125 | INFO     | __main__:run_case:30 - case7: archive case
# 2021-02-17 15:07:10.570 | INFO     | __main__:run_case:35 - case1: success!!!
# 2021-02-17 15:07:12.880 | INFO     | __main__:run_case:30 - case2: archive case
# 2021-02-17 15:07:14.083 | INFO     | __main__:run_case:30 - case8: archive case
# 2021-02-17 15:07:14.083 | INFO     | __main__:run_case:30 - case3: archive case
# 2021-02-17 15:07:14.248 | INFO     | __main__:run_case:30 - case5: archive case
# 2021-02-17 15:07:30.592 | INFO     | __main__:run_case:35 - case7: success!!!
# 2021-02-17 15:07:33.051 | INFO     | __main__:run_case:35 - case2: success!!!
# 2021-02-17 15:07:39.112 | INFO     | __main__:run_case:35 - case5: success!!!
# 2021-02-17 15:07:40.246 | INFO     | __main__:run_case:35 - case3: success!!!
# 2021-02-17 15:07:41.458 | INFO     | __main__:run_case:35 - case8: success!!!
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# # calc metrics

# %%
def calc_metrics(path_mod):
    var_list = ['dni','dhi'] # dni: direct normal irradiance DHI: diffuse horizontal irradiance
    varn_obs = ['obs_swddni', 'obs_swddif']
    varn_mod = ['SWDDNI','SWDDIF']
    
    path_base = "/ss/hsdc/home/tzhang/wrf_solar/"
    path_obs = path_base+"sgpradflux10long_area_mean.c1.20160619_1200UTC.nc"
    path_def = "/S2/gscr2/tzhang/big_data/UQ/tune/runwrf_def/wrfout_d02_2016-06-19_06:00:00"
    
    fid_obs = Dataset(path_obs)
    fid_def = Dataset(path_def)
    fid_mod = Dataset(path_mod)
    
    Chi = 0
    for i, var in enumerate(var_list):
        #print(var)
        
        var_obs = fid_obs.variables[varn_obs[i]][:]
        var_mod = fid_mod.variables[varn_mod[i]][36:]
        var_def = fid_def.variables[varn_mod[i]][36:]
        
        var_mod_avg = np.mean(var_mod, axis=(1,2))
        var_def_avg = np.mean(var_def, axis=(1,2))
        
        #print(var_obs.shape)
        #print(var_mod_avg.shape)
        #print(var_def_avg.shape)
        
        theta_mod = 0
        for j in range(var_obs.shape[0]):
            theta_mod += (var_obs[j] - var_mod_avg[j]) ** 2
            
        theta_def = 0
        for j in range(var_obs.shape[0]):
            theta_def += (var_obs[j] - var_def_avg[j]) ** 2
            
        Chi += (theta_mod / theta_def)
        
    Chi /= len(var_list)
    
    return Chi, np.mean(fid_mod.variables['SWDDNI']), np.mean(fid_mod.variables['SWDDIF'])
            
all_cases = os.listdir("/S2/gscr2/tzhang/big_data/UQ/tune")
for idx in range(12):
    print(str(idx)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(idx)+"/wrfout_d02_2016-06-19_06:00:00")[0])

print(str(13)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(13)+"/wrfout_d02_2016-06-19_06:00:00")[0])
print(str(14)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(14)+"/wrfout_d02_2016-06-19_06:00:00")[0])
print(str(16)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(16)+"/wrfout_d02_2016-06-19_06:00:00")[0])
for idx in range(16,87):
    print(str(idx)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(idx)+"/wrfout_d02_2016-06-19_06:00:00")[0])

for idx in range(103,140):
    print(str(idx)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(idx)+"/wrfout_d02_2016-06-19_06:00:00")[0])
# Out:
# 0:  0.8086014250448218
# 1:  0.8415257825689977
# 2:  0.8466482503061028
# 3:  0.9190987950053155
# 4:  0.8412276981336335
# 5:  0.9770383323115949
# 6:  1.0764576022688366
# 7:  0.9262690184475022
# 8:  0.8138767655338754
# 9:  0.8647407965094136
# 10:  0.9482645280095798
# 11:  0.9213464111101468
# 13:  1.0014244807919868
# 14:  0.9776943639401492
# 16:  14.883599103894632
# 16:  14.883599103894632
# 17:  17.21416105796571
# 18:  0.8823314020866967
# 19:  0.8538337565257983
# 20:  1.0515511904093393
# 21:  0.966339808164346
# 22:  0.9746878636525915
# 23:  1.0261412778892156
# 24:  0.9048487747007476
# 25:  0.8401766704352442
# 26:  0.9898694017711764
# 27:  1.0346477480081517
# 28:  0.9232145155545632
# 29:  0.8989215101625021
# 30:  0.9811308356965073
# 31:  1.0187012059249891
# 32:  1.1065825662714153
# 33:  0.9028228418039647
# 34:  0.9480436378744888
# 35:  0.9909354417225318
# 36:  0.8592205479804562
# 37:  0.995015089788442
# 38:  0.9428757519454265
# 39:  0.9871057574793141
# 40:  0.9726987110896652
# 41:  0.9172147659083205
# 42:  0.8887159347281633
# 43:  0.9521701467883759
# 44:  0.9500404011132001
# 45:  0.9455184345250631
# 46:  0.9513846706632113
# 47:  0.8406529657903217
# 48:  1.0019986265998653
# 49:  0.9245491952700422
# 50:  1.0046177812908954
# 51:  0.8651388915136158
# 52:  0.9015678097583371
# 53:  1.0458723793674627
# 54:  0.7731930972296797
# 55:  0.9845017759547547
# 56:  0.9792512454833658
# 57:  0.9830731391713949
# 58:  1.0072237788629976
# 59:  0.9301920558331638
# 60:  0.8837592808232224
# 61:  0.8540367399700588
# 62:  0.9589061185395926
# 63:  0.8565940729514838
# 64:  0.962155074475767
# 65:  0.9340072779344881
# 66:  0.8568919145450065
# 67:  0.951018278139289
# 68:  0.9563238491200636
# 69:  1.0174525648683277
# 70:  1.0675764496738351
# 71:  0.933124897249563
# 72:  0.8862900850627623
# 73:  0.9962977047544768
# 74:  1.088546527414168
# 75:  0.9091753381415408
# 76:  0.9643445737720703
# 77:  0.9477758267581167
# 78:  0.8981977090369944
# 79:  0.9130540301828236
# 80:  0.9089917409551869
# 81:  0.9122205974054847
# 82:  0.9670190706081874
# 83:  0.9720774234067042
# 84:  1.0932683737425293
# 85:  0.9058756841914155
# 86:  0.9960642550373148
# 103:  0.7731930972296797
# 104:  0.9808680096764544
# 105:  0.7731930972296797
# 106:  0.7731930972296797
# 107:  0.7731930972296797
# 108:  0.7731930972296797
# 109:  0.7731930972296797
# 110:  0.7731930972296797
# 111:  0.7731930972296797
# 112:  0.7731930972296797
# 113:  0.7731930972296797
# 114:  0.7731930972296797
# 115:  0.7731930972296797
# 116:  0.7731930972296797
# 117:  0.7731930972296797
# 118:  0.7731930972296797
# 119:  0.7731930972296797
# 120:  0.7731930972296797
# 121:  0.7731930972296797
# 122:  0.7731930972296797
# 123:  0.7731930972296797
# 124:  0.7731930972296797
# 125:  0.7731930972296797
# 126:  0.7731930972296797
# 127:  0.7731930972296797
# 128:  0.7731930972296797
# 129:  0.7731930972296797
# 130:  0.7731930972296797
# 131:  0.7731930972296797
# 132:  0.7731930972296797
# 133:  0.7731930972296797
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-16dc22f0bfd8> in <module>
#      52
#      53 for idx in range(103,140):
# ---> 54     print(str(idx)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/Iter"+str(idx)+"/wrfout_d02_2016-06-19_06:00:00")[0])
#      55
#      56
#
# <ipython-input-4-16dc22f0bfd8> in calc_metrics(path_mod)
#      10     fid_obs = Dataset(path_obs)
#      11     fid_def = Dataset(path_def)
# ---> 12     fid_mod = Dataset(path_mod)
#      13
#      14     Chi = 0
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/S2/gscr2/tzhang/big_data/UQ/tune/Iter134/wrfout_d02_2016-06-19_06:00:00'

# %%
for idx in range(58):
    print(str(idx)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune1/Iter"+str(idx)+"/wrfout_d02_2016-06-19_06:00:00")[0])
    
for idx in range(75,140):
    print(str(idx)+": ",calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune1/Iter"+str(idx)+"/wrfout_d02_2016-06-19_06:00:00")[0])
# Out:
# 0:  0.7185683910695972
# 1:  0.7805678499652386
# 2:  0.7821531804273437
# 3:  0.8504605079401721
# 4:  1.0042508507133512
# 5:  0.925031869219805
# 6:  0.848375612125577
# 7:  0.8728998694508294
# 8:  1.0806361860039104
# 9:  0.9432784633507407
# 10:  0.9504140385306361
# 11:  1.0117210353947745
# 12:  0.8810180957652385
# 13:  0.8956986393330012
# 14:  0.9489207459762283
# 15:  0.9411051700766202
# 16:  1.0333822643238508
# 17:  0.841220221635363
# 18:  0.9005196385093224
# 19:  0.8881447145534493
# 20:  0.9122269749589753
# 21:  0.9745002083164425
# 22:  0.9149974886788799
# 23:  0.9132285962244576
# 24:  0.9753657490884724
# 25:  0.8922588369785602
# 26:  0.9118109384606122
# 27:  0.9931460093242079
# 28:  0.866557082311658
# 29:  0.8576281169734101
# 30:  0.9325019997145161
# 31:  0.928613877108576
# 32:  1.0097197136148928
# 33:  0.9415594869579369
# 34:  0.8494688071224851
# 35:  0.8502672366064125
# 36:  0.881562063168485
# 37:  0.9144325408200031
# 38:  1.0179069653820183
# 39:  0.9177882873506606
# 40:  0.824725184920439
# 41:  1.0049455402532277
# 42:  1.0269221478148984
# 43:  0.9848161501731357
# 44:  0.9042897411372153
# 45:  0.975602389758027
# 46:  0.8514056184222474
# 47:  0.8809133152472317
# 48:  0.9399924911377966
# 49:  0.9010744771784581
# 50:  0.8583078009881346
# 51:  0.8895628061876684
# 52:  0.9514445847854787
# 53:  0.9444170036748173
# 54:  0.9288372228527337
# 55:  0.9894606350745748
# 56:  0.9422465875813064
# 57:  0.9583968917618589
# 75:  0.8951255191796028
# 76:  0.8920360427563805
# 77:  0.9133387915134397
# 78:  0.9336000910787663
# 79:  1.0160937101693093
# 80:  0.9304551457618166
# 81:  0.970749829463015
# 82:  0.9260285925766851
# 83:  1.0489981560722956
# 84:  0.8368096084272015
# 85:  0.9650392149978504
# 86:  0.9671510615487631
# 87:  0.898677649957967
# 88:  0.9074566852415948
# 89:  0.8362212978922468
# 90:  0.9086796265683756
# 91:  0.8639195923525591
# 92:  0.8193635578005576
# 93:  1.0384687849866783
# 94:  0.922666886237293
# 95:  0.8720651156634661
# 96:  0.9124376100726564
# 97:  0.9204939273862192
# 98:  0.8674215269632808
# 99:  0.9124376100726564
# 100:  0.8342972613452823
# 101:  0.8720651156634661
# 102:  0.9122694147374395
# 103:  0.8342972613452823
# 104:  0.9122694147374395
# 105:  0.8720651156634661
# 106:  0.8342972613452823
# 107:  0.9122694147374395
# 108:  0.8342972613452823
# 109:  0.8342972613452823
# 110:  0.8342972613452823
# 111:  0.9122694147374395
# 112:  0.8342972613452823
# 113:  0.8342972613452823
# 114:  0.8342972613452823
# 115:  0.9122694147374395
# 116:  0.8342972613452823
# 117:  0.7185683910695972
# 118:  0.8342972613452823
# 119:  0.7185683910695972
# 120:  0.7185683910695972
# 121:  0.7185683910695972
# 122:  0.7185683910695972
# 123:  0.7185683910695972
# 124:  0.7185683910695972
# 125:  0.7185683910695972
# 126:  0.7185683910695972
# 127:  0.7185683910695972
# 128:  0.7185683910695972
# 129:  0.7185683910695972
# 130:  0.7185683910695972
# 131:  0.7185683910695972
# 132:  0.7185683910695972
# 133:  0.7185683910695972
# 134:  0.7185683910695972
# 135:  0.7185683910695972
# 136:  0.7185683910695972
# 137:  0.7185683910695972
# 138:  0.7185683910695972
# 139:  0.7185683910695972

# %% [markdown]
# # sensitive analysis

# %%
all_cases = os.listdir("/S2/gscr2/tzhang/big_data/UQ/tune/")
all_cases_data = pd.DataFrame(columns=['vdis','beta_con','DNI','DIF','mcpi'])

for case in all_cases:
    fp = open("/S2/gscr2/tzhang/big_data/UQ/tune/"+case+"/namelist.input")
    for i, line in enumerate(fp):
        if i == 85:
            vdis = float(line.split('=')[1])
        if i == 87:
            beta_con = float(line.split('=')[1])
    fp.close() 
        
    mcpi,DNI,DIF = calc_metrics("/S2/gscr2/tzhang/big_data/UQ/tune/"+case+"/wrfout_d02_2016-06-19_06:00:00")
    all_cases_data = all_cases_data.append({'vdis':vdis,'beta_con':beta_con,'DNI':DNI,'DIF':DIF,'mcpi':mcpi},ignore_index=True)

# %%
print(all_cases_data.loc[55,:])
# Out:
# vdis                           1.311842
# beta_con    1127924859569167096872960.0
# DNI                           290.54355
# DIF                           125.74615
# mcpi                           0.773193
# Name: 55, dtype: object
#         vdis      beta_con        DNI         DIF      mcpi
# 0   1.311846  1.129999e+24   296.8351  123.998436  0.950040
# 1   1.311842  1.127925e+24  290.54355   125.74615  0.773193
# 2   1.311829  1.127949e+24   296.5752   123.71484  0.996298
# 3   1.090377  4.618288e+23  293.89227  124.445694  0.841228
# 4   1.311840  1.127931e+24   295.8408   124.13849  0.967019
# ..       ...           ...        ...         ...       ...
# 95  1.311835  1.127937e+24  293.88504   125.03027  0.947776
# 96  1.310868  1.124133e+24  294.12665   124.76754  0.942876
# 97  1.311787  1.127330e+24  296.75482   123.38134  1.004618
# 98  1.311841  1.127925e+24   295.6923    124.3236  0.905876
# 99  1.311757  1.139181e+24  298.71808   123.24321  1.106583
#
# [100 rows x 5 columns]

# %%
all_cases_data = all_cases_data[all_cases_data.mcpi<1.1]

from matplotlib import cm
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20,13))

surf = ax.plot_trisurf(all_cases_data['vdis'],all_cases_data['beta_con']/10e20,1-all_cases_data['mcpi'],cmap=cm.jet)

# %%
all_cases_data.head()
all_cases_data.drop_duplicates(subset=['mcpi'], inplace=True)

# %%
from matplotlib import cm
fh=18

all_temp = all_cases_data.iloc[:,:]

fig, axes = plt.subplots(1,1,figsize=(10.5,5.5),squeeze=False)
aa = axes[0][0].scatter(all_temp['vdis'],all_temp['beta_con']/10e20,c=all_temp['mcpi'],s=180,cmap="RdBu_r")
print(all_temp.shape)

#add_common_colorbar(fig,aa,list(axes[0]),"mcpi",orientation='vertical',nbins=9,fontsize=fh)
axes[0][0].set_title("Best Performance: 0.773, 23% improvement",fontsize=fh)
axes[0][0].set_xlim([0,1.4])
axes[0][0].set_ylim([0,1400])
axes[0][0].scatter(para_default[0],para_default[1]/10e20,c=1.0,marker='+',s=180)
axes[0][0].scatter(all_temp.iloc[1,0],all_temp.iloc[1,1]/10e20,c=0.77,s=180, cmap="RdBu_r")
axes[0][0].scatter(all_temp.iloc[1,0],all_temp.iloc[1,1]/10e20,c='yellow',marker='*',s=180)
axes[0][0].tick_params(axis='x', labelsize=fh)
axes[0][0].tick_params(axis='y', labelsize=fh)

axes[0][0].set_xlabel("Relative Dispersion",fontsize=fh)
axes[0][0].set_ylabel("Condensation Rate Constant",fontsize=fh)

cbar = fig.colorbar(aa, ax=axes[0][0])
#cbar.ax.set_title("Tuning metric",fontsize=fh)
cbar.set_label("Tuning metric",fontsize=fh)
cbar.ax.tick_params(labelsize=fh)

plt.savefig("tuning performance.pdf")
# Out:
# (85, 5)

# %%
import matplotlib
from matplotlib import ticker

plt.figure(figsize=(16,9))
fig, axes = plt.subplots(1,1,figsize=(16,8),subplot_kw={'projection':"3d"}, squeeze=False)

#plt.scatter(vdis_list,beta_con_list,c=mcpi_list, s=80)
#plt.colorbar()

cmap = matplotlib.cm.get_cmap('magma')
print(cmap)
aa = axes[0][0].scatter3D(vdis_list,beta_con_list,mcpi_list, c=mcpi_list, s=85,cmap='hot')
#aa = axes.scatter3D(vdis_list,beta_con_list,mcpi_list, s=85,cmap=cmap)
add_common_colorbar(fig,aa,list(axes[0]),"mcpi",orientation='vertical',nbins=9,fontsize=15)
# Out:
# <matplotlib.colors.ListedColormap object at 0x2ab721cb3b20>

# %%
from matplotlib import cm
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20,13))

surf = ax.plot_trisurf(np.array(vdis_list),np.array(beta_con_list)/10e20,np.array(mcpi_list),cmap=cm.jet)

# %%
paras_pd_new = paras_pd[paras_pd.mcpi<1.1]

Xs = np.array(paras_pd_new.iloc[:,1])
Ys = np.array(paras_pd_new.iloc[:,2])
Zs = np.array(paras_pd_new.iloc[:,3])

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20,13))

surf = ax.plot_trisurf(Xs,Ys/10e20,1-Zs, linewidth=0,cmap=cm.jet)

# %%
from matplotlib import ticker
def add_common_colorbar(fig,im,axes,units,orientation='vertical',nbins=9,fontsize=15):
    '''
    Feb 12, 2021: generate a common colorbar for several specific subplots.
    For example, subplots on the same row or the same column.
    -----------------------
    Inputs:
    fig -- 
    im -- return handle. 
    axes --- the list for all subplots.
    units --- unit of colorbar.
    orientation --- direction of colorbar.
    nbins --- number of labeled ticks. default: 9
    fontsize --- label fontsize for colorbar. 
    '''
    pos1 = axes[-1].get_position() # get the original position for the last subplot 
    if orientation == 'vertical':
        pos2 = [pos1.x0 + pos1.width + 0.01, pos1.y0 + 0.1,  pos1.width / 20.0, pos1.height/1.2 ]   
    else:
        pos2 = [pos1.x0, pos1.y0 - 0.01, pos1.width, pos1.height / 25.0]
        
    cbar_ax = fig.add_axes(pos2)
    cb = fig.colorbar(im,ax=axes, orientation=orientation, cax=cbar_ax)
    cb.set_label(units,fontsize=fontsize)
    cb.ax.tick_params(labelsize=fontsize)
    tick_locator = ticker.MaxNLocator(nbins=nbins)
    cb.locator = tick_locator
    cb.update_ticks()

# %%
paras_pd
# Out:
#         case      vdis      beta_con      mcpi
# 0    case112  1.086555  1.028007e+23  0.986757
# 1    case134  0.024595  1.011225e+24  0.944964
# 2    case984  1.206095  9.026819e+23  0.866796
# 3    case105  0.162205  1.017905e+24  0.977691
# 4    case162  1.112965  4.367803e+23  0.888637
# ..       ...       ...           ...       ...
# 861  case614  1.032345  4.150717e+23  0.908447
# 862   case47  0.712645  5.770518e+23  0.932675
# 863  case516  0.562525  6.004303e+23  0.942240
# 864  case657  0.555575  9.577885e+23  0.888888
# 865   case76  0.203905  4.985666e+23  0.927382
#
# [866 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing

paras_pd_new = paras_pd[paras_pd.mcpi<2]

#X = preprocessing.normalize(paras_pd.iloc[:,1:3],norm='l2')
X = preprocessing.normalize(paras_pd_new.iloc[:,1:3])
X = np.array(paras_pd_new.iloc[:,1:3])
y = np.array(paras_pd_new.iloc[:,3])
print(X.shape,y.shape)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# (817, 2) (817,)

# %%
params = {'n_estimators': 500,
          'max_depth': 4,
          'min_samples_split': 5,
          'learning_rate': 0.01,
          'loss': 'ls'}

reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(mse)

plt.scatter(y_test,y_pred)
plt.xlim(0.9,1)
# Out:
# 0.0031559593311335558
# (0.9, 1.0)

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
reg = GridSearchCV(SVR(kernel='rbf', gamma=0.1),
                   param_grid={"C": [1e0, 1e1, 1e2, 1e3],
                               "gamma": np.logspace(-2, 2, 5)})

reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(mse)

plt.scatter(y_test,y_pred)
plt.xlim(0.9,1)
# Out:
# 0.0038257648190673024
# (0.9, 1.0)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import WhiteKernel, ExpSineSquared
gp_kernel = ExpSineSquared(3.0, 5.0, periodicity_bounds=(1e-2, 1e1)) \
    + WhiteKernel(1e-1)
reg = GaussianProcessRegressor(kernel=gp_kernel)

reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(mse)

plt.scatter(y_test,y_pred)
plt.xlim(0.9,1)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-93-e32deeba7eac> in <module>
#       5 reg = GaussianProcessRegressor(kernel=gp_kernel)
#       6
# ----> 7 reg.fit(X_train, y_train)
#       8
#       9 y_pred = reg.predict(X_test)
#
# ~/soft/miniconda3/envs/luffy/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py in fit(self, X, y)
#     263         K[np.diag_indices_from(K)] += self.alpha
#     264         try:
# --> 265             self.L_ = cholesky(K, lower=True)  # Line 2
#     266             # self.L_ changed, self._K_inv needs to be recomputed
#     267             self._K_inv = None
#
# ~/soft/miniconda3/envs/luffy/lib/python3.8/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      86
#      87     """
# ---> 88     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#      89                          check_finite=check_finite)
#      90     return c
#
# ~/soft/miniconda3/envs/luffy/lib/python3.8/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      36     if info > 0:
# ---> 37         raise LinAlgError("%d-th leading minor of the array is not positive "
#      38                           "definite" % info)
#      39     if info < 0:
#
# LinAlgError: ("The kernel, ExpSineSquared(length_scale=3, periodicity=5) + WhiteKernel(noise_level=0.1), is not returning a positive definite matrix. Try gradually increasing the 'alpha' parameter of your GaussianProcessRegressor estimator.", '5-th leading minor of the array is not positive definite')

# %%
import xgboost as xgb
reg = xgb.XGBRegressor(objective ='reg:linear', n_estimators = 100, seed = 123) 

reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(mse)

plt.scatter(y_test,y_pred)
plt.xlim(0.9,1)
plt.ylim(0.9,1)
# Out:
# [14:09:34] WARNING: ../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# 0.00395915642307555
# (0.9, 1.0)

# %%
from sklearn.linear_model import HuberRegressor, Ridge
reg = Ridge(alpha=0.0, random_state=0, normalize=True)

reg.fit(X_train, y_train)

y_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(mse)

plt.scatter(y_test,y_pred)
plt.xlim(0.9,1)
plt.ylim(0.9,1)
# Out:
# 0.003031035298769253
# (0.9, 1.0)

# %%
import skccm.data as data

rx1 = 3.72 #determines chaotic behavior of the x1 series
rx2 = 3.72 #determines chaotic behavior of the x2 series
b12 = 0.2 #Influence of x1 on x2
b21 = 0.01 #Influence of x2 on x1
ts_length = 1000
x1,x2 = data.coupled_logistic(rx1,rx2,b12,b21,ts_length)

print(x1.shape)
print(x2.shape)
# Out:
# (1000,)
# (1000,)

# %%
import skccm as ccm
lag = 1
embed = 2
e1 = ccm.Embed(x1)
e2 = ccm.Embed(x2)
X1 = e1.embed_vectors_1d(lag,embed)
X2 = e2.embed_vectors_1d(lag,embed)

print(X1.shape)
# Out:
# (999, 2)

# %%
from skccm.utilities import train_test_split

#split the embedded time series
x1tr, x1te, x2tr, x2te = train_test_split(X1,X2, percent=.75)

CCM = ccm.CCM() #initiate the class

#library lengths to test
len_tr = len(x1tr)
lib_lens = np.arange(10, len_tr, len_tr/20, dtype='int')

#test causation
CCM.fit(x1tr,x2tr)
x1p, x2p = CCM.predict(x1te, x2te,lib_lengths=lib_lens)

sc1,sc2 = CCM.score()

# %%
plt.plot(sc1)
plt.plot(sc2)

# %% [markdown]
# # scam sensitivity
