# %%
import pandas as pd
import numpy as np
import sys
import re

# %% [markdown]
# # global config

# %%
case_home = '/global/cscratch1/sd/zhangtao/E3SM/'
cases = ['20220120.ne30pg2_EC30to60E2r2.ml_BCU.F2010',
        '20220120.ne30pg2_EC30to60E2r2.dilute_dcape.F2010']

# %% [markdown]
# # parameters

# %%
p_names = ['ice_sed_ai', 'clubb_c1','clubb_gamma_coef','zmconv_tau','zmconv_dmpdz']

p_dataset = pd.DataFrame()

for c in cases:
    c_path = case_home+c+"/run/atm_in"
    print(c)
    tmp = {}
    for pn in p_names:
        val_str = os.popen(f'grep -w {pn} {c_path}').read().split('=')[1]
        val = float(val_str)
        tmp[pn] = val
    tmp = pd.DataFrame(tmp,index=[c])
    p_dataset = pd.concat([p_dataset,tmp])
# Out:
# 20220120.ne30pg2_EC30to60E2r2.ml_BCU.F2010
# 20220120.ne30pg2_EC30to60E2r2.dilute_dcape.F2010

# %%
p_dataset
# Out:
#                                                   ice_sed_ai  clubb_c1  \
# 20220120.ne30pg2_EC30to60E2r2.ml_BCU.F2010             500.0       2.4
# 20220120.ne30pg2_EC30to60E2r2.dilute_dcape.F2010       500.0       2.4
#
#                                                   clubb_gamma_coef  \
# 20220120.ne30pg2_EC30to60E2r2.ml_BCU.F2010                    0.12
# 20220120.ne30pg2_EC30to60E2r2.dilute_dcape.F2010              0.12
#
#                                                   zmconv_tau  zmconv_dmpdz
# 20220120.ne30pg2_EC30to60E2r2.ml_BCU.F2010            3600.0       -0.0007
# 20220120.ne30pg2_EC30to60E2r2.dilute_dcape.F2010      3600.0       -0.0007

# %% [markdown]
# # metrics

# %%
seasons = ['ANN','DJF','MAM','JJA','SON']
seasons = ['ANN']
mets = ['LWCF','PRECT','PSL','RELHUM','SWCF','TREFHT','U200','U850','Z500']

diag_home = "/global/cfs/cdirs/e3sm/www/golaz/E3SM/QBO/"
diag_suffix = "20210813.F2010.ne30pg2_oECv3.chrysalis/e3sm_diags/atm_monthly_180x360_aave/model_vs_obs_0011-0020/viewer/table-data/ANN_metrics_table.csv"

# %%
met_dataset = pd.DataFrame()
for i in range(1,251):
    tmp = {}
    diag_path = f'{diag_home}workdir.{i}/{diag_suffix}'
    diag_data = pd.read_csv(diag_path)
    var_names = diag_data['Variables'].values
    dataset = diag_data['RMSE'].values
    for vn,data in zip(var_names,dataset):
        tmp[vn] = data
    tmp = pd.DataFrame(tmp, index=['workdir.'+str(i)])
    met_dataset = pd.concat([met_dataset,tmp])

# %%
met_dataset
# Out:
#              PRECT global GPCP_v2.2  PRECT global GPCP_v2.3  \
# workdir.1                     1.711                   1.703
# workdir.2                     1.817                   1.809
# workdir.3                     1.834                   1.826
# workdir.4                     1.524                   1.517
# workdir.5                     0.970                   0.971
# ...                             ...                     ...
# workdir.246                   0.981                   0.981
# workdir.247                   1.245                   1.238
# workdir.248                   1.294                   1.288
# workdir.249                   1.642                   1.635
# workdir.250                   1.836                   1.828
#
#              TREFHT land_60S90N CRU  RESTOM global ceres_ebaf_toa_v4.1  \
# workdir.1                     2.186                              7.057
# workdir.2                     2.079                              9.113
# workdir.3                     2.211                              9.604
# workdir.4                     2.037                              9.130
# workdir.5                     2.113                              7.764
# ...                             ...                                ...
# workdir.246                   2.225                              9.617
# workdir.247                   2.171                              7.243
# workdir.248                   2.283                              9.099
# workdir.249                   2.137                              6.940
# workdir.250                   2.048                              8.505
#
#              FLUT global ceres_ebaf_toa_v4.1  \
# workdir.1                             11.766
# workdir.2                             13.726
# workdir.3                             13.269
# workdir.4                              8.114
# workdir.5                              6.023
# ...                                      ...
# workdir.246                            7.154
# workdir.247                            6.056
# workdir.248                            6.259
# workdir.249                           10.405
# workdir.250                           13.621
#
#              FSNTOA global ceres_ebaf_toa_v4.1  \
# workdir.1                               13.770
# workdir.2                               17.554
# workdir.3                               17.986
# workdir.4                               13.848
# workdir.5                                9.200
# ...                                        ...
# workdir.246                             12.275
# workdir.247                              9.649
# workdir.248                             11.657
# workdir.249                             12.768
# workdir.250                             16.696
#
#              FLNS global ceres_ebaf_surface_v4.1  \
# workdir.1                                 10.650
# workdir.2                                 12.879
# workdir.3                                 13.161
# workdir.4                                 11.713
# workdir.5                                  9.816
# ...                                          ...
# workdir.246                               11.539
# workdir.247                                9.096
# workdir.248                               10.973
# workdir.249                               10.339
# workdir.250                               12.312
#
#              FSNS global ceres_ebaf_surface_v4.1  LHFLX global OAFlux  \
# workdir.1                                 15.665               31.155
# workdir.2                                 19.838               31.420
# workdir.3                                 20.383               30.424
# workdir.4                                 15.957               26.375
# workdir.5                                 10.660               22.317
# ...                                          ...                  ...
# workdir.246                               13.646               17.457
# workdir.247                               11.234               26.337
# workdir.248                               13.468               23.399
# workdir.249                               14.605               30.131
# workdir.250                               18.918               32.044
#
#              SHFLX global OAFlux  ...  FLNS global MERRA2  \
# workdir.1                  7.700  ...              10.752
# workdir.2                  7.803  ...              10.150
# workdir.3                  7.908  ...               9.998
# workdir.4                  7.744  ...               9.932
# workdir.5                  8.880  ...              10.280
# ...                          ...  ...                 ...
# workdir.246                8.538  ...               9.171
# workdir.247                7.029  ...              12.500
# workdir.248                7.304  ...              10.373
# workdir.249                7.670  ...              10.969
# workdir.250                7.736  ...              10.311
#
#              NET_FLUX_SRF global MERRA2  PRECT global MERRA2  \
# workdir.1                        21.727                1.508
# workdir.2                        21.151                1.578
# workdir.3                        21.188                1.586
# workdir.4                        20.941                1.411
# workdir.5                        20.603                1.436
# ...                                 ...                  ...
# workdir.246                      19.658                1.562
# workdir.247                      21.952                1.296
# workdir.248                      20.361                1.285
# workdir.249                      22.057                1.498
# workdir.250                      21.285                1.595
#
#              TAUXY ocean MERRA2  TREFHT global ERA5  TREFHT land ERA5  \
# workdir.1                 0.020               1.357             2.177
# workdir.2                 0.020               1.348             2.159
# workdir.3                 0.022               1.409             2.264
# workdir.4                 0.019               1.343             2.167
# workdir.5                 0.015               1.308             2.226
# ...                         ...                 ...               ...
# workdir.246               0.018               1.310             2.190
# workdir.247               0.016               1.321             2.133
# workdir.248               0.017               1.378             2.210
# workdir.249               0.020               1.347             2.166
# workdir.250               0.020               1.333             2.136
#
#              TREFHT global MERRA2  TREFHT land MERRA2  \
# workdir.1                   1.227               2.023
# workdir.2                   1.191               1.944
# workdir.3                   1.249               2.047
# workdir.4                   1.164               1.897
# workdir.5                   1.220               2.019
# ...                           ...                 ...
# workdir.246                 1.224               1.992
# workdir.247                 1.213               2.016
# workdir.248                 1.275               2.108
# workdir.249                 1.217               2.000
# workdir.250                 1.182               1.937
#
#              PminusE global GPCP_OAFLux  PminusE global COREv2_Flux
# workdir.1                         1.277                       1.555
# workdir.2                         1.315                       1.593
# workdir.3                         1.308                       1.594
# workdir.4                         1.218                       1.460
# workdir.5                         0.929                       1.050
# ...                                 ...                         ...
# workdir.246                       0.943                       1.106
# workdir.247                       1.084                       1.291
# workdir.248                       1.080                       1.309
# workdir.249                       1.297                       1.546
# workdir.250                       1.320                       1.609
#
# [250 rows x 30 columns]

# %% [markdown]
# # surrogate
