# %%
import pandas as pd
import numpy as np
import sys
import os
import xgboost as xgb
import matplotlib.pyplot as plt

import sys
sys.path.append('/global/homes/z/zhangtao/E3SM/UQ_python/opt/TuRBO/')

from turbo import Turbo1
import torch

# %%
from cycler import cycler
my_cycler = (cycler(color=['#94c8d8','#FE9A84','#296540','#E63F39','#C3AAD1',
              '#D5AC5A','#F4B6C3','#B4BCCA','#DBD468','#B1D3E1','#8b1821']))

fh = 15
plt.rcParams['figure.figsize'] = (18,12)
plt.rcParams['axes.prop_cycle'] = my_cycler
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 9#12
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['axes.labelsize'] = fh
plt.rcParams['xtick.labelsize'] = fh
plt.rcParams['ytick.labelsize'] = fh
plt.rcParams['axes.titlesize'] = fh
plt.rcParams['figure.titlesize'] = fh

# %% [markdown]
# # global config

# %% [markdown]
# # parameters

# %%
p_names = ['ice_sed_ai', 'clubb_c1','clubb_gamma_coef','zmconv_tau','zmconv_dmpdz']
p_dataset = pd.read_csv('freeform_list.txt',header=None, sep='\s+')
p_dataset.columns = p_names
p_dataset = p_dataset.iloc[:250,:]
p_dataset
# Out:
#       ice_sed_ai  clubb_c1  clubb_gamma_coef    zmconv_tau  zmconv_dmpdz
# 0     440.233349  2.148841          0.214851  10184.253210     -0.001369
# 1    1131.606212  2.313776          0.415906  14039.817200     -0.001355
# 2     371.193911  3.831670          0.347189  13000.055200     -0.001641
# 3    1255.126697  4.627875          0.205403  14348.781430     -0.000168
# 4     987.057711  3.092444          0.155059   2727.223375     -0.001744
# ..           ...       ...               ...           ...           ...
# 245   785.688346  4.838557          0.487458   3925.122979     -0.000126
# 246   463.042167  1.706742          0.100070   8598.076313     -0.000184
# 247   399.401551  1.554390          0.467934  12279.736250     -0.000103
# 248   463.482015  2.064071          0.210404   8771.434647     -0.000987
# 249  1090.605389  1.734183          0.370416  12970.073720     -0.001827
#
# [250 rows x 5 columns]

# %% [markdown]
# # metrics from PPE

# %%
seasons = ['ANN','DJF','MAM','JJA','SON']
seasons = ['ANN']
mets = ['LWCF','PRECT','PSL','RELHUM','SWCF','TREFHT','U200','U850','Z500']

diag_home = "/global/cfs/cdirs/e3sm/www/golaz/E3SM/QBO/"
diag_suffix = "20210813.F2010.ne30pg2_oECv3.chrysalis/e3sm_diags/atm_monthly_180x360_aave/model_vs_obs_0011-0020/viewer/table-data/ANN_metrics_table.csv"

diag_home = "/global/homes/z/zhangtao/e3sm_www/SNL_PPE.v2/diag/"
diag_suffix="ANN_metrics_table.csv"

# %% [markdown]
# ## RMSE

# %%
met_dataset = pd.DataFrame()
for i in range(1,251):
    tmp = {}
    diag_path = f'{diag_home}workdir.{i}/{diag_suffix}'
    diag_data = pd.read_csv(diag_path)
    var_names = diag_data['Variables'].values
    dataset = diag_data['RMSE'].values
    for vn,data in zip(var_names,dataset):
        tmp[vn] = data
    tmp = pd.DataFrame(tmp, index=['workdir.'+str(i)])
    met_dataset = pd.concat([met_dataset,tmp])
    
sel_metrics=['PRECT global GPCP_v2.3','SWCF global ceres_ebaf_toa_v4.1',
            'LWCF global ceres_ebaf_toa_v4.1', 'FLUT global ceres_ebaf_toa_v4.1',
            'FSNTOA global ceres_ebaf_toa_v4.1']
sel_name = ['PRECT','SWCF','LWCF','FLUT','FSNTOA']

met_dataset = met_dataset[sel_metrics]
met_dataset.columns = sel_name
met_dataset

metrics = met_dataset.columns

# %%
met_dataset
# Out:
#              PRECT    SWCF    LWCF    FLUT  FSNTOA
# workdir.1    1.646  14.072  10.549  11.766  13.770
# workdir.2    1.740  17.915  12.247  13.726  17.554
# workdir.3    1.756  18.222  11.825  13.269  17.986
# workdir.4    1.458  14.202   8.064   8.114  13.848
# workdir.5    0.957   9.648   6.187   6.023   9.200
# ...            ...     ...     ...     ...     ...
# workdir.246  0.965  12.527   6.273   7.154  12.275
# workdir.247  1.199  10.362   5.139   6.056   9.649
# workdir.248  1.240  12.242   5.827   6.259  11.657
# workdir.249  1.584  13.130   9.589  10.405  12.768
# workdir.250  1.763  17.056  12.092  13.621  16.696
#
# [250 rows x 5 columns]

# %%
fig,ax = plt.subplots(figsize=(7,5.5))

ax.scatter(met_dataset['LWCF'],met_dataset['PRECT'])
ax.scatter(4.929,0.923,color='r',marker='*')
ax.set_xlabel('RMSE of LWCF')
ax.set_ylabel('RMSE of PRECT')
# Out:
# Text(0, 0.5, 'RMSE of PRECT')

# %% [markdown]
# ## skill score

# %% [markdown]
# $E(m)=\log\left[\frac{\left(\sigma_{\mathrm{obs}}/\sigma_{\mathrm{mod}}+\sigma_{\mathrm{mod}}/\sigma_{\mathrm{obs}}\right)^{2}\bigl(1+R_{0}\bigr)^{k}}{4(1+R)^{k}}\right]$

# %%
met_dataset = pd.DataFrame()
for i in range(1,251):
    tmp = {}
    diag_path = f'{diag_home}workdir.{i}/{diag_suffix}'
    diag_data = pd.read_csv(diag_path)
    var_names = diag_data['Variables'].values
    sd_obs = diag_data['Ref._STD'].values
    sd_mod = diag_data['Test_STD'].values
    corr = diag_data['Correlation'].values
    tl_scr = np.log((((sd_obs/sd_mod + sd_mod/sd_obs) ** 2) * (2 ** 4))/(4 * (1 + corr) ** 4))
    
    for vn,data in zip(var_names,tl_scr):
        tmp[vn] = data
    tmp = pd.DataFrame(tmp, index=['workdir.'+str(i)])
    met_dataset = pd.concat([met_dataset,tmp])
    
sel_metrics=['PRECT global GPCP_v2.3','SWCF global ceres_ebaf_toa_v4.1',
            'LWCF global ceres_ebaf_toa_v4.1', 'FLUT global ceres_ebaf_toa_v4.1',
            'FSNTOA global ceres_ebaf_toa_v4.1']
sel_name = ['PRECT','SWCF','LWCF','FLUT','FSNTOA']

met_dataset = met_dataset[sel_metrics]
met_dataset.columns = sel_name
met_dataset

metrics = met_dataset.columns

# %%
met_dataset
# Out:
#                 PRECT      SWCF      LWCF      FLUT    FSNTOA
# workdir.1    0.455817  0.372675  0.708319  0.111772  0.021771
# workdir.2    0.506212  0.482624  0.832698  0.125508  0.027167
# workdir.3    0.524236  0.492425  0.793642  0.122462  0.025359
# workdir.4    0.391781  0.354172  0.337344  0.058856  0.019309
# workdir.5    0.199753  0.226967  0.209140  0.036770  0.012363
# ...               ...       ...       ...       ...       ...
# workdir.246  0.231573  0.365011  0.265598  0.055896  0.020207
# workdir.247  0.270791  0.208305  0.202940  0.036933  0.012180
# workdir.248  0.301660  0.315984  0.226876  0.041220  0.018645
# workdir.249  0.432742  0.343657  0.585828  0.092888  0.020312
# workdir.250  0.515350  0.465314  0.836941  0.127150  0.024791
#
# [250 rows x 5 columns]

# %% [markdown]
# # metrics from tuning

# %%
seasons = ['ANN','DJF','MAM','JJA','SON']
seasons = ['ANN']
mets = ['LWCF','PRECT','PSL','RELHUM','SWCF','TREFHT','U200','U850','Z500']

cases = ['20210813.F2010.ne30pg2_oECv3.BO.chrysalis',
        '20210813.F2010.ne30pg2_oECv3.chrysalis',
        '20210813.F2010.ne30pg2_oECv3.tune.chrysalis']
diag_home = "/global/homes/z/zhangtao/pwww/"
diag_suffix = "viewer/table-data/ANN_metrics_table.csv"

met_dataset = pd.DataFrame()
for c in cases:
    tmp = {}
    diag_path = f'{diag_home}{c}/{diag_suffix}'
    diag_data = pd.read_csv(diag_path)
    var_names = diag_data['Variables'].values
    dataset = diag_data['RMSE'].values
    for vn,data in zip(var_names,dataset):
        tmp[vn] = data
    tmp = pd.DataFrame(tmp, index=[c])
    met_dataset = pd.concat([met_dataset,tmp])

# %%
aa = met_dataset.transpose()
aa.columns = ['BO','CNTL','MAP']
aa.to_csv(f'{diag_home}tune_table.csv')
aa.to_html(f'{diag_home}tune_table.html')

# %% [markdown]
# # surrogate

# %%
train_x = p_dataset.iloc[:200,:]
train_y = met_dataset.iloc[:200,:]
test_x = p_dataset.iloc[-50:,:]
test_y = met_dataset.iloc[-50:,:]

# %%
kernel = 1.0 * RBF(length_scale=1e1, length_scale_bounds=(1e-2, 500000)) + WhiteKernel(
    noise_level=1, noise_level_bounds=(1e-5, 1e1)
)

regs = {'Linear':LinearRegression(),
       'gp':GaussianProcessRegressor(kernel=kernel),
       #'xgb': xgb.XGBRegressor(n_estimators=600, nthread=8, max_depth=7,scale_pos_weight=3.5)
       'xgb': xgb.XGBRegressor(n_estimators=600, nthread=8, max_depth=7) 
       }

# %%
for m in metrics:
    print(m)
    fig, ax = plt.subplots(1,3,figsize=(12,4))
    
    for k,n in enumerate(regs):
        reg = regs[n]
        reg.fit(train_x, train_y.loc[:,m])
        pred = reg.predict(test_x)
        #rmse = mean_squared_error(test_y.loc[:,m], pred, squared=False)
        score = reg.score(test_x,test_y.loc[:,m])
        #print(f'{m}=\t\t\t\t{score:.2f}')
    
        ax[k].scatter(test_y.loc[:,m],pred, label=n)
        ax[k].set_title(f'{n}, $R^2$={score:.2f}')
        ax[k].set_xlim([np.min(pred)*0.95,np.max(pred)*1.05])
        ax[k].set_ylim([np.min(pred)*0.95,np.max(pred)*1.05])
        ax[k].plot([0,1],[0,1], transform=ax[k].transAxes, color='k')
        
    fig.suptitle(m)
    
    plt.tight_layout()
# Out:
# PRECT
# SWCF
# LWCF
# FLUT
# FSNTOA
# /global/cfs/projectdirs/m2136/backup/conda/envs/dushu/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %% [markdown]
# # tuning with surrogate

# %%
class metrics:
    def surrogate1(self): #"LWCF" or "PRECT"
        self.reg1 = xgb.XGBRegressor(n_estimators=600, nthread=8, max_depth=7,scale_pos_weight=3.5)
        self.reg2 = xgb.XGBRegressor(n_estimators=600, nthread=8, max_depth=7,scale_pos_weight=3.5)
        
        train_m = train_y.loc[:,'LWCF']
        self.reg1.fit(train_x,train_m)
        train_m = train_y.loc[:,'PRECT']
        self.reg2.fit(train_x,train_m)
        
        self.ref_a = 5.29
        self.ref_b = 0.891
        
    def cost_fun1(self,X):
        return self.reg1.predict(X) 
    
    def cost_fun2(self,X):
        return self.reg2.predict(X)
    
    def cost_fun3(self,X):
        a = self.reg1.predict(X)/self.ref_a
        b = self.reg2.predict(X)/self.ref_b
        return a + b 
    
    def validate(self,X):
        a = self.reg1.predict(X)[0]
        b = self.reg2.predict(X)[0]
        
        print(f'{X}')
        print(f'No normalization LWCF={a:.3f} PRECT={b:.3f}')
        print(f'normalization LWCF={a/self.ref_a:.3f} PRECT={b/self.ref_b:.3f}')

# %%
mm = metrics()
mm.surrogate1()

# %% [markdown]
# ## OAT

# %%
from smt.sampling_methods import LHS

# %%
pbounds = {'ai': (350, 1400), 'c1': (1.0, 5.0),
          'coef': (0.1, 0.5), 'tau': (1800, 14400),
          'dmpdz': (-2.0e-3, -0.1e-3)}

defaults = {'ai': 500, 'c1':2.4, 'coef':0.12, 'tau':3600, 'dmpdz':-0.7e-3}

fig, ax = plt.subplots(3,2,figsize=(16,12))

for i,var in enumerate(pbounds.keys()):
    pb = pbounds[var]
    oat_samps = np.linspace(pb[0],pb[1],500)

    oat_pd = pd.DataFrame()
    oat_pd[var] = oat_samps

    for v in pbounds.keys():
        if v != var:
            oat_pd[v] = defaults[v]


    oat_pd = oat_pd[pbounds.keys()]
    oat_pd.columns = train_x.columns

    pred1 = mm.cost_fun1(oat_pd)
    pred2 = mm.cost_fun2(oat_pd)

    
    ax[i//2][i%2].plot(oat_samps,pred1,label='LWCF')
    ax1 = ax[i//2][i%2].twinx()
    ax1.plot(oat_samps,pred2,label='PRECT',color='#FE9A84')
    
    ax[i//2][i%2].legend(loc='upper left')
    ax1.legend(loc='upper center')
    
    ax1.set_title(var)

plt.tight_layout()

# %% [markdown]
# ## BayesianOpt

# %%
def fun1(ai, c1, coef, tau, dmpdz):
    X = np.array([ai, c1, coef, tau, dmpdz]).reshape(1,-1)
    pred_y = - (mm.cost_fun3(X))
    return pred_y[0]
    
#fun1(1.3,1.02E20)

# %%
pbounds = {'ai': (350, 1400), 'c1': (1.0, 5.0),
          'coef': (0.1, 0.5), 'tau': (1800, 14400),
          'dmpdz': (-2.0e-3, -0.1e-3)}

#default: [500, 1.335, 0.32, 3600, -0.7e-3]

# %%
Boptimizer = BayesianOptimization(
    f=fun1,
    pbounds=pbounds,
    random_state=50,
)

Boptimizer.maximize(
    init_points=50,
    n_iter=500,
)
# Out:
# |   iter    |  target   |    ai     |    c1     |   coef    |   dmpdz   |    tau    |
# -------------------------------------------------------------------------------------
# | 1         | -0.512    | 869.3     | 1.912     | 0.2022    | -0.001247 | 6.554e+03 |
# | 2         | -0.3247   | 1.396e+03 | 2.633     | 0.4088    | -0.000555 | 5.706e+03 |
# | 3         | -0.4939   | 713.9     | 2.407     | 0.1582    | -0.000151 | 1.326e+04 |
# | 4         | -0.3721   | 938.0     | 2.254     | 0.4553    | -0.000718 | 6.728e+03 |
# | 5         | -0.6399   | 882.5     | 3.096     | 0.4712    | -0.000914 | 1.022e+04 |
# | 6         | -0.7146   | 404.9     | 2.308     | 0.1226    | -0.001658 | 1.347e+04 |
# | 7         | -0.7198   | 1.335e+03 | 3.856     | 0.3931    | -0.001123 | 1.353e+04 |
# | 8         | -0.2993   | 776.7     | 3.733     | 0.36      | -0.000862 | 4.598e+03 |
# | 9         | -0.7175   | 1.066e+03 | 4.512     | 0.4187    | -0.001179 | 1.337e+04 |
# | 10        | -0.3031   | 1.171e+03 | 3.903     | 0.1499    | -0.000259 | 6.685e+03 |
# | 11        | -0.721    | 659.7     | 3.467     | 0.2871    | -0.001515 | 1.237e+04 |
# | 12        | -0.2678   | 537.6     | 1.908     | 0.364     | -0.00109  | 2.725e+03 |
# | 13        | -0.6836   | 495.9     | 1.449     | 0.2911    | -0.000973 | 1.387e+04 |
# | 14        | -0.2904   | 963.0     | 3.107     | 0.4689    | -0.000253 | 4.975e+03 |
# | 15        | -0.6792   | 1.067e+03 | 4.857     | 0.1908    | -0.000639 | 1.185e+04 |
# | 16        | -0.3355   | 1.334e+03 | 4.415     | 0.2686    | -0.00199  | 2.239e+03 |
# | 17        | -0.7296   | 364.6     | 3.356     | 0.2532    | -0.001782 | 1.269e+04 |
# | 18        | -0.7054   | 1.213e+03 | 3.95      | 0.4361    | -0.001237 | 1.123e+04 |
# | 19        | -0.4711   | 937.6     | 3.453     | 0.2192    | -0.000855 | 7.164e+03 |
# | 20        | -0.27     | 915.5     | 2.947     | 0.3       | -0.000256 | 5.112e+03 |
# | 21        | -0.259    | 402.2     | 2.851     | 0.2633    | -0.001075 | 2.688e+03 |
# | 22        | -0.7271   | 961.2     | 4.948     | 0.1836    | -0.001596 | 1.391e+04 |
# | 23        | -0.5513   | 1.092e+03 | 3.372     | 0.2523    | -0.000786 | 8.131e+03 |
# | 24        | -0.7292   | 444.3     | 2.189     | 0.4313    | -0.001667 | 1.32e+04  |
# | 25        | -0.2895   | 967.7     | 1.066     | 0.248     | -0.00192  | 3.404e+03 |
# | 26        | -0.2875   | 538.2     | 1.666     | 0.4535    | -0.000278 | 4.766e+03 |
# | 27        | -0.3411   | 777.6     | 2.885     | 0.4321    | -0.001445 | 3.99e+03  |
# | 28        | -0.5264   | 831.1     | 4.61      | 0.338     | -0.001216 | 6.911e+03 |
# | 29        | -0.6581   | 673.9     | 2.272     | 0.266     | -0.000787 | 1.182e+04 |
# | 30        | -0.7468   | 388.9     | 3.938     | 0.409     | -0.001536 | 1.421e+04 |
# | 31        | -0.7089   | 1.059e+03 | 4.571     | 0.1972    | -0.001902 | 1.074e+04 |
# | 32        | -0.6602   | 1.355e+03 | 1.091     | 0.4653    | -0.000616 | 1.384e+04 |
# | 33        | -0.6124   | 636.8     | 1.682     | 0.229     | -0.001473 | 7.982e+03 |
# | 34        | -0.5601   | 487.3     | 3.953     | 0.1561    | -0.000915 | 8.52e+03  |
# | 35        | -0.2392   | 595.2     | 2.908     | 0.2859    | -0.000468 | 2.034e+03 |
# | 36        | -0.2606   | 1.098e+03 | 2.004     | 0.3642    | -0.000790 | 2.518e+03 |
# | 37        | -0.2727   | 1.105e+03 | 2.36      | 0.3199    | -0.000585 | 4.049e+03 |
# | 38        | -0.5398   | 613.2     | 1.536     | 0.1603    | -0.000215 | 1.404e+04 |
# | 39        | -0.6826   | 499.7     | 1.783     | 0.1402    | -0.001845 | 1.148e+04 |
# | 40        | -0.7233   | 570.9     | 2.849     | 0.1336    | -0.00137  | 1.425e+04 |
# | 41        | -0.2587   | 1.295e+03 | 4.461     | 0.2537    | -0.000668 | 2.268e+03 |
# | 42        | -0.4476   | 876.4     | 1.456     | 0.3935    | -0.00117  | 5.92e+03  |
# | 43        | -0.3138   | 1.139e+03 | 2.052     | 0.294     | -0.001988 | 1.866e+03 |
# | 44        | -0.4493   | 946.0     | 2.412     | 0.25      | -0.001306 | 5.694e+03 |
# | 45        | -0.4091   | 529.4     | 4.916     | 0.41      | -0.000152 | 8.421e+03 |
# | 46        | -0.5051   | 600.4     | 2.941     | 0.3357    | -0.001049 | 7.214e+03 |
# | 47        | -0.3287   | 613.4     | 1.23      | 0.3573    | -0.001522 | 4.213e+03 |
# | 48        | -0.5597   | 886.2     | 2.523     | 0.4668    | -0.001901 | 6.557e+03 |
# | 49        | -0.4267   | 872.6     | 3.317     | 0.423     | -0.000304 | 7.749e+03 |
# | 50        | -0.3681   | 453.6     | 3.91      | 0.2956    | -0.000665 | 6.303e+03 |
# | 51        | -0.5046   | 940.9     | 3.155     | 0.1651    | -0.000916 | 6.723e+03 |
# | 52        | -0.3345   | 774.4     | 4.792     | 0.2071    | -0.000989 | 4.599e+03 |
# | 53        | -0.2559   | 1.309e+03 | 1.719     | 0.2304    | -0.000940 | 2.265e+03 |
# | 54        | -0.2499   | 1.301e+03 | 3.431     | 0.132     | -0.000569 | 2.24e+03  |
# | 55        | -0.2487   | 578.5     | 2.082     | 0.3897    | -0.000270 | 2.017e+03 |
# | 56        | -0.5181   | 916.8     | 1.084     | 0.4498    | -0.001439 | 6.757e+03 |
# | 57        | -0.2817   | 565.3     | 4.869     | 0.1084    | -0.001733 | 2.041e+03 |
# | 58        | -0.2564   | 602.4     | 3.707     | 0.3312    | -0.000953 | 2.008e+03 |
# | 59        | -0.3584   | 786.9     | 1.805     | 0.1696    | -0.001894 | 4.574e+03 |
# | 60        | -0.2863   | 551.5     | 4.165     | 0.4965    | -0.000940 | 2.747e+03 |
# | 61        | -0.3555   | 799.8     | 3.75      | 0.3964    | -0.00151  | 4.614e+03 |
# | 62        | -0.3006   | 1.114e+03 | 4.795     | 0.3686    | -0.001726 | 2.539e+03 |
# | 63        | -0.2402   | 1.122e+03 | 2.025     | 0.1241    | -0.000318 | 2.503e+03 |
# | 64        | -0.2573   | 573.6     | 1.335     | 0.3012    | -0.001182 | 2.727e+03 |
# | 65        | -0.2536   | 569.6     | 2.583     | 0.2297    | -0.001012 | 2.693e+03 |
# | 66        | -0.231    | 599.2     | 1.496     | 0.142     | -0.000268 | 2.709e+03 |
# | 67        | -0.2404   | 594.4     | 2.161     | 0.1928    | -0.000353 | 2.685e+03 |
# | 68        | -0.251    | 1.106e+03 | 3.916     | 0.1938    | -0.000370 | 2.476e+03 |
# | 69        | -0.2412   | 634.0     | 2.521     | 0.1057    | -0.000176 | 2.701e+03 |
# | 70        | -0.261    | 639.0     | 3.091     | 0.4152    | -0.000799 | 2.664e+03 |
# | 71        | -0.273    | 1.137e+03 | 2.662     | 0.3918    | -0.001153 | 2.46e+03  |
# | 72        | -0.2824   | 614.7     | 3.291     | 0.405     | -0.001652 | 2.636e+03 |
# | 73        | -0.2694   | 436.1     | 3.241     | 0.2449    | -0.001074 | 2.681e+03 |
# | 74        | -0.2586   | 422.6     | 2.457     | 0.2603    | -0.001018 | 2.719e+03 |
# | 75        | -0.2968   | 606.7     | 4.224     | 0.4721    | -0.001546 | 2.751e+03 |
# | 76        | -0.2708   | 481.9     | 2.302     | 0.1631    | -0.001925 | 2.708e+03 |
# | 77        | -0.2438   | 490.4     | 1.77      | 0.2837    | -0.000318 | 2.659e+03 |
# | 78        | -0.2773   | 523.9     | 2.768     | 0.3819    | -0.001476 | 2.666e+03 |
# | 79        | -0.2532   | 576.8     | 1.472     | 0.4862    | -0.000717 | 2.639e+03 |
# | 80        | -0.2817   | 456.6     | 4.815     | 0.4032    | -0.000137 | 2.633e+03 |
# | 81        | -0.2501   | 684.3     | 1.994     | 0.3377    | -0.000667 | 2.686e+03 |
# | 82        | -0.2538   | 410.5     | 3.074     | 0.4317    | -0.000302 | 2.647e+03 |
# | 83        | -0.2844   | 692.9     | 1.777     | 0.3431    | -0.001829 | 2.642e+03 |
# | 84        | -0.2375   | 673.7     | 1.825     | 0.1141    | -0.000473 | 2.734e+03 |
# | 85        | -0.2665   | 724.0     | 1.662     | 0.1557    | -0.001622 | 2.739e+03 |
# | 86        | -0.287    | 732.1     | 4.959     | 0.2324    | -0.00148  | 2.682e+03 |
# | 87        | -0.2646   | 671.6     | 2.462     | 0.4898    | -0.000255 | 2.777e+03 |
# | 88        | -0.282    | 497.1     | 3.476     | 0.4334    | -0.001579 | 2.607e+03 |
# | 89        | -0.2898   | 548.4     | 4.84      | 0.3986    | -0.001079 | 2.618e+03 |
# | 90        | -0.2429   | 714.9     | 3.038     | 0.1924    | -0.000746 | 2.801e+03 |
# | 91        | -0.2921   | 678.4     | 4.448     | 0.1767    | -0.001533 | 2.84e+03  |
# | 92        | -0.3053   | 727.5     | 4.379     | 0.3999    | -0.00184  | 2.848e+03 |
# | 93        | -0.26     | 755.8     | 2.218     | 0.3923    | -0.000778 | 2.809e+03 |
# | 94        | -0.2753   | 772.5     | 4.737     | 0.2944    | -0.000763 | 2.746e+03 |
# | 95        | -0.2738   | 465.8     | 2.9       | 0.4252    | -0.001241 | 2.758e+03 |
# | 96        | -0.2618   | 1.251e+03 | 1.0       | 0.1284    | -0.0001   | 2.233e+03 |
# | 97        | -0.2783   | 418.8     | 1.949     | 0.4807    | -0.001513 | 2.778e+03 |
# | 98        | -0.253    | 1.271e+03 | 1.23      | 0.2122    | -0.000459 | 2.194e+03 |
# | 99        | -0.2821   | 368.4     | 1.79      | 0.3293    | -0.001334 | 2.751e+03 |
# | 100       | -0.2652   | 814.6     | 1.963     | 0.3277    | -0.001183 | 2.781e+03 |
# | 101       | -0.2518   | 1.178e+03 | 1.802     | 0.2432    | -0.000368 | 2.5e+03   |
# | 102       | -0.2706   | 805.9     | 2.145     | 0.3626    | -0.00115  | 2.829e+03 |
# | 103       | -0.2882   | 1.204e+03 | 4.233     | 0.1694    | -0.001635 | 2.455e+03 |
# | 104       | -0.2759   | 351.6     | 1.483     | 0.4407    | -0.001099 | 2.673e+03 |
# | 105       | -0.3476   | 1.222e+03 | 5.0       | 0.5       | -0.002    | 2.188e+03 |
# | 106       | -0.2541   | 1.229e+03 | 2.7       | 0.1189    | -0.000109 | 2.505e+03 |
# | 107       | -0.2999   | 1.198e+03 | 5.0       | 0.5       | -0.00156  | 2.547e+03 |
# | 108       | -0.2632   | 372.0     | 3.847     | 0.2938    | -0.000686 | 2.613e+03 |
# | 109       | -0.2664   | 427.4     | 1.763     | 0.1886    | -0.001404 | 2.58e+03  |
# | 110       | -0.2613   | 865.1     | 3.77      | 0.4832    | -0.000541 | 2.816e+03 |
# | 111       | -0.4167   | 916.1     | 1.961     | 0.1197    | -0.001621 | 5.053e+03 |
# | 112       | -0.2741   | 363.1     | 3.761     | 0.432     | -0.000938 | 2.56e+03  |
# | 113       | -0.2349   | 407.2     | 1.602     | 0.2932    | -0.000543 | 2.537e+03 |
# | 114       | -0.2882   | 356.9     | 2.848     | 0.1267    | -0.001887 | 2.506e+03 |
# | 115       | -0.2793   | 463.9     | 2.731     | 0.4599    | -0.00136  | 2.546e+03 |
# | 116       | -0.2812   | 447.1     | 3.352     | 0.2852    | -0.001658 | 2.486e+03 |
# | 117       | -0.2478   | 849.8     | 2.544     | 0.2454    | -0.000170 | 2.868e+03 |
# | 118       | -0.2763   | 908.3     | 3.827     | 0.2576    | -0.001514 | 2.863e+03 |
# | 119       | -0.2658   | 395.7     | 3.468     | 0.4148    | -0.000209 | 2.478e+03 |
# | 120       | -0.2908   | 878.9     | 3.981     | 0.5       | -0.0001   | 2.912e+03 |
# | 121       | -0.2745   | 811.1     | 1.503     | 0.4788    | -0.001304 | 2.905e+03 |
# | 122       | -0.2819   | 840.3     | 4.911     | 0.3959    | -0.000801 | 2.73e+03  |
# | 123       | -0.314    | 926.7     | 1.238     | 0.3706    | -0.000756 | 5.165e+03 |
# | 124       | -0.2768   | 929.8     | 1.087     | 0.4616    | -0.001456 | 2.812e+03 |
# | 125       | -0.2561   | 890.4     | 2.273     | 0.4445    | -0.000241 | 2.77e+03  |
# | 126       | -0.2347   | 929.1     | 1.529     | 0.1646    | -0.000743 | 2.73e+03  |
# | 127       | -0.2645   | 975.1     | 4.76      | 0.3514    | -0.000280 | 2.759e+03 |
# | 128       | -0.2353   | 965.5     | 2.314     | 0.1125    | -0.000470 | 2.686e+03 |
# | 129       | -0.2418   | 905.6     | 1.91      | 0.2484    | -0.000701 | 2.659e+03 |
# | 130       | -0.2462   | 895.2     | 1.044     | 0.4681    | -0.000328 | 2.695e+03 |
# | 131       | -0.2384   | 952.9     | 1.266     | 0.2095    | -0.000380 | 2.643e+03 |
# | 132       | -0.2629   | 1.011e+03 | 2.102     | 0.3835    | -0.000969 | 2.71e+03  |
# | 133       | -0.2418   | 1.013e+03 | 1.869     | 0.1575    | -0.00076  | 2.642e+03 |
# | 134       | -0.2607   | 995.1     | 3.769     | 0.4852    | -0.000530 | 2.59e+03  |
# | 135       | -0.283    | 940.4     | 4.827     | 0.3408    | -0.000900 | 2.593e+03 |
# | 136       | -0.2641   | 1.066e+03 | 3.281     | 0.3118    | -0.000128 | 2.609e+03 |
# | 137       | -0.2573   | 1.076e+03 | 3.327     | 0.3769    | -0.000192 | 2.671e+03 |
# | 138       | -0.2534   | 1.043e+03 | 4.313     | 0.3858    | -0.000612 | 2.561e+03 |
# | 139       | -0.2789   | 853.6     | 4.28      | 0.1291    | -0.001207 | 2.655e+03 |
# | 140       | -0.246    | 1.022e+03 | 3.276     | 0.1648    | -0.000607 | 2.51e+03  |
# | 141       | -0.2577   | 981.3     | 3.302     | 0.3347    | -0.000214 | 2.522e+03 |
# | 142       | -0.2677   | 998.0     | 2.071     | 0.2356    | -0.001618 | 2.461e+03 |
# | 143       | -0.2613   | 1.041e+03 | 2.887     | 0.2211    | -0.001389 | 2.754e+03 |
# | 144       | -0.2981   | 1.071e+03 | 4.88      | 0.3901    | -0.001415 | 2.432e+03 |
# | 145       | -0.2815   | 1.08e+03  | 2.505     | 0.2998    | -0.00186  | 2.722e+03 |
# | 146       | -0.2884   | 985.2     | 4.813     | 0.2256    | -0.001525 | 2.817e+03 |
# | 147       | -0.2678   | 1.122e+03 | 3.47      | 0.1802    | -0.001234 | 2.642e+03 |
# | 148       | -0.2942   | 932.5     | 2.723     | 0.4978    | -0.001929 | 2.482e+03 |
# | 149       | -0.263    | 798.9     | 1.958     | 0.3136    | -0.001407 | 2.68e+03  |
# | 150       | -0.306    | 762.5     | 4.873     | 0.3731    | -0.001966 | 2.619e+03 |
# | 151       | -0.2532   | 648.4     | 4.716     | 0.2927    | -0.000597 | 2.074e+03 |
# | 152       | -0.2411   | 679.9     | 1.835     | 0.1436    | -0.000814 | 2.012e+03 |
# | 153       | -0.2462   | 710.0     | 2.875     | 0.37      | -0.000617 | 2.06e+03  |
# | 154       | -0.2469   | 752.8     | 2.883     | 0.4085    | -0.000385 | 2.006e+03 |
# | 155       | -0.2762   | 711.8     | 4.891     | 0.3811    | -0.000837 | 1.943e+03 |
# | 156       | -0.2661   | 784.3     | 3.924     | 0.1553    | -0.001249 | 2.061e+03 |
# | 157       | -0.294    | 698.2     | 4.143     | 0.326     | -0.001518 | 2.107e+03 |
# | 158       | -0.2542   | 773.7     | 2.486     | 0.4352    | -0.000265 | 1.953e+03 |
# | 159       | -0.2575   | 812.4     | 1.54      | 0.2959    | -0.001425 | 1.997e+03 |
# | 160       | -0.2797   | 644.1     | 3.423     | 0.4862    | -0.001693 | 1.944e+03 |
# | 161       | -0.2513   | 1.149e+03 | 3.903     | 0.4246    | -0.000541 | 2.7e+03   |
# | 162       | -0.2682   | 1.188e+03 | 1.245     | 0.4275    | -0.001125 | 2.674e+03 |
# | 163       | -0.2774   | 1.199e+03 | 2.229     | 0.4598    | -0.001281 | 2.727e+03 |
# | 164       | -0.2759   | 1.142e+03 | 4.085     | 0.3276    | -0.000852 | 2.752e+03 |
# | 165       | -0.2383   | 832.4     | 2.83      | 0.2398    | -0.000585 | 1.923e+03 |
# | 166       | -0.2638   | 785.5     | 3.396     | 0.3133    | -0.001191 | 1.904e+03 |
# | 167       | -0.2337   | 864.7     | 2.608     | 0.169     | -0.000705 | 1.972e+03 |
# | 168       | -0.2567   | 858.1     | 1.604     | 0.2146    | -0.001304 | 2.051e+03 |
# | 169       | -0.2496   | 821.4     | 1.952     | 0.3409    | -0.000318 | 1.868e+03 |
# | 170       | -0.2632   | 883.7     | 1.495     | 0.1955    | -0.001751 | 1.903e+03 |
# | 171       | -0.2726   | 883.1     | 2.332     | 0.3612    | -0.001349 | 1.845e+03 |
# | 172       | -0.2798   | 919.3     | 4.485     | 0.3035    | -0.001619 | 2.014e+03 |
# | 173       | -0.2648   | 827.3     | 3.448     | 0.4128    | -0.000970 | 2.113e+03 |
# | 174       | -0.2712   | 915.6     | 2.556     | 0.4233    | -0.0012   | 1.956e+03 |
# | 175       | -0.2427   | 901.1     | 1.06      | 0.322     | -0.000170 | 2.088e+03 |
# | 176       | -0.2822   | 887.1     | 3.937     | 0.3414    | -0.001255 | 2.157e+03 |
# | 177       | -0.2509   | 955.2     | 3.727     | 0.1213    | -0.000454 | 2.109e+03 |
# | 178       | -0.259    | 952.4     | 3.799     | 0.4757    | -0.000398 | 2.172e+03 |
# | 179       | -0.2346   | 974.7     | 1.476     | 0.1198    | -0.000202 | 2.056e+03 |
# | 180       | -0.2762   | 1.022e+03 | 4.281     | 0.1948    | -0.001027 | 2.053e+03 |
# | 181       | -0.2686   | 1.005e+03 | 1.347     | 0.347     | -0.001168 | 2.114e+03 |
# | 182       | -0.2637   | 989.0     | 2.427     | 0.2134    | -0.001646 | 1.987e+03 |
# | 183       | -0.2931   | 1.004e+03 | 1.528     | 0.41      | -0.001949 | 2.188e+03 |
# | 184       | -0.2589   | 976.1     | 4.401     | 0.2741    | -0.000242 | 1.921e+03 |
# | 185       | -0.2673   | 940.2     | 1.87      | 0.1198    | -0.001761 | 1.858e+03 |
# | 186       | -0.2433   | 773.2     | 1.174     | 0.2481    | -0.000652 | 2.13e+03  |
# | 187       | -0.2709   | 805.7     | 1.133     | 0.1999    | -0.001793 | 2.192e+03 |
# | 188       | -0.2583   | 1.043e+03 | 2.298     | 0.204     | -0.001557 | 1.952e+03 |
# | 189       | -0.2481   | 599.3     | 1.0       | 0.1873    | -0.0001   | 2.103e+03 |
# | 190       | -0.2396   | 1.011e+03 | 1.507     | 0.1707    | -0.000820 | 1.864e+03 |
# | 191       | -0.2625   | 1.058e+03 | 3.25      | 0.4399    | -0.000185 | 1.867e+03 |
# | 192       | -0.2321   | 977.2     | 2.004     | 0.1581    | -0.000631 | 1.818e+03 |
# | 193       | -0.261    | 1.05e+03  | 3.113     | 0.1815    | -0.0014   | 1.813e+03 |
# | 194       | -0.2786   | 633.9     | 3.703     | 0.1426    | -0.001838 | 2.147e+03 |
# | 195       | -0.2761   | 740.8     | 4.36      | 0.451     | -0.000858 | 2.166e+03 |
# | 196       | -0.2288   | 1.07e+03  | 1.487     | 0.1658    | -0.000532 | 2.007e+03 |
# | 197       | -0.2639   | 925.3     | 4.957     | 0.1642    | -0.000271 | 1.801e+03 |
# | 198       | -0.2761   | 1.113e+03 | 1.904     | 0.3778    | -0.001324 | 2.025e+03 |
# | 199       | -0.2757   | 1.103e+03 | 1.454     | 0.2518    | -0.001902 | 1.929e+03 |
# | 200       | -0.2626   | 1.086e+03 | 3.879     | 0.1567    | -0.001011 | 2.798e+03 |
# | 201       | -0.2703   | 1.083e+03 | 1.496     | 0.3783    | -0.001311 | 2.072e+03 |
# | 202       | -0.265    | 571.1     | 2.979     | 0.1483    | -0.001689 | 2.155e+03 |
# | 203       | -0.2821   | 542.4     | 1.754     | 0.4989    | -0.001206 | 2.113e+03 |
# | 204       | -0.2523   | 804.8     | 2.12      | 0.3657    | -0.000798 | 1.807e+03 |
# | 205       | -0.2898   | 748.4     | 2.53      | 0.3394    | -0.001952 | 1.848e+03 |
# | 206       | -0.3079   | 1.056e+03 | 4.733     | 0.4802    | -0.001398 | 2.849e+03 |
# | 207       | -0.2863   | 927.4     | 2.841     | 0.3637    | -0.001592 | 2.223e+03 |
# | 208       | -0.2766   | 576.9     | 4.504     | 0.2204    | -0.001187 | 1.952e+03 |
# | 209       | -0.2796   | 1.149e+03 | 4.62      | 0.2953    | -0.001051 | 2.827e+03 |
# | 210       | -0.2578   | 1.031e+03 | 4.585     | 0.1043    | -0.000321 | 1.908e+03 |
# | 211       | -0.2755   | 1.278e+03 | 1.891     | 0.1529    | -0.001805 | 2.469e+03 |
# | 212       | -0.2821   | 1.309e+03 | 4.799     | 0.1451    | -0.001056 | 2.522e+03 |
# | 213       | -0.2616   | 857.1     | 2.734     | 0.2156    | -0.001375 | 2.231e+03 |
# | 214       | -0.2886   | 806.6     | 1.559     | 0.3324    | -0.001951 | 2.277e+03 |
# | 215       | -0.2389   | 871.2     | 1.305     | 0.2487    | -0.000702 | 2.287e+03 |
# | 216       | -0.2519   | 926.8     | 3.819     | 0.2703    | -0.000443 | 2.295e+03 |
# | 217       | -0.2669   | 905.9     | 4.358     | 0.179     | -0.000952 | 2.35e+03  |
# | 218       | -0.2424   | 991.0     | 2.714     | 0.1317    | -0.000749 | 2.288e+03 |
# | 219       | -0.3121   | 962.5     | 1.396     | 0.1463    | -0.00199  | 2.345e+03 |
# | 220       | -0.2579   | 838.8     | 1.713     | 0.3013    | -0.001213 | 2.331e+03 |
# | 221       | -0.2657   | 999.1     | 3.148     | 0.2373    | -0.001324 | 2.241e+03 |
# | 222       | -0.297    | 1.049e+03 | 2.558     | 0.3848    | -0.001793 | 2.268e+03 |
# | 223       | -0.2988   | 861.0     | 3.004     | 0.4352    | -0.001969 | 2.379e+03 |
# | 224       | -0.274    | 850.8     | 2.01      | 0.3855    | -0.001449 | 1.804e+03 |
# | 225       | -0.262    | 931.6     | 2.901     | 0.2532    | -0.001457 | 2.059e+03 |
# | 226       | -0.2806   | 1.075e+03 | 3.956     | 0.2199    | -0.001584 | 2.138e+03 |
# | 227       | -0.2794   | 522.5     | 1.705     | 0.417     | -0.001914 | 1.981e+03 |
# | 228       | -0.2731   | 1.207e+03 | 1.0       | 0.5       | -0.0001   | 2.795e+03 |
# | 229       | -0.2643   | 682.9     | 3.42      | 0.1427    | -0.001274 | 1.884e+03 |
# | 230       | -0.2708   | 623.6     | 3.703     | 0.2812    | -0.001754 | 1.867e+03 |
# | 231       | -0.2711   | 558.1     | 4.108     | 0.2864    | -0.001021 | 1.878e+03 |
# | 232       | -0.2743   | 519.3     | 4.718     | 0.352     | -0.000837 | 1.914e+03 |
# | 233       | -0.2512   | 651.8     | 3.443     | 0.1227    | -0.000978 | 1.809e+03 |
# | 234       | -0.2617   | 564.1     | 3.223     | 0.2425    | -0.001179 | 1.827e+03 |
# | 235       | -0.2817   | 497.2     | 2.663     | 0.4406    | -0.001799 | 1.848e+03 |
# | 236       | -0.2656   | 1.214e+03 | 3.825     | 0.2568    | -0.001013 | 2.861e+03 |
# | 237       | -0.2948   | 693.9     | 4.363     | 0.3297    | -0.001865 | 1.835e+03 |
# | 238       | -0.2659   | 1.184e+03 | 1.983     | 0.2644    | -0.001205 | 2.91e+03  |
# | 239       | -0.2557   | 1.23e+03  | 1.077     | 0.4943    | -0.000216 | 2.949e+03 |
# | 240       | -0.2918   | 1.261e+03 | 3.797     | 0.4378    | -0.001364 | 2.905e+03 |
# | 241       | -0.3031   | 1.165e+03 | 3.123     | 0.2927    | -0.001737 | 2.962e+03 |
# | 242       | -0.2564   | 1.097e+03 | 4.648     | 0.3905    | -0.000354 | 1.978e+03 |
# | 243       | -0.2846   | 1.278e+03 | 2.36      | 0.3671    | -0.001094 | 2.992e+03 |
# | 244       | -0.2813   | 1.27e+03  | 1.583     | 0.3084    | -0.001648 | 2.833e+03 |
# | 245       | -0.2992   | 874.4     | 4.277     | 0.2859    | -0.00198  | 2.596e+03 |
# | 246       | -0.2574   | 585.4     | 1.95      | 0.2569    | -0.001203 | 2.218e+03 |
# | 247       | -0.2326   | 642.1     | 2.83      | 0.162     | -0.000449 | 2.242e+03 |
# | 248       | -0.2855   | 644.7     | 3.628     | 0.4955    | -0.001703 | 2.287e+03 |
# | 249       | -0.2481   | 656.5     | 3.544     | 0.2074    | -0.000489 | 2.195e+03 |
# | 250       | -0.2575   | 709.5     | 3.372     | 0.3172    | -0.000156 | 2.234e+03 |
# | 251       | -0.2852   | 570.3     | 2.094     | 0.47      | -0.001621 | 2.269e+03 |
# | 252       | -0.2569   | 716.5     | 3.924     | 0.4558    | -0.000664 | 2.3e+03   |
# | 253       | -0.2629   | 757.9     | 3.223     | 0.2531    | -0.001126 | 2.351e+03 |
# | 254       | -0.2697   | 600.4     | 3.035     | 0.4587    | -0.001199 | 1.802e+03 |
# | 255       | -0.2436   | 692.4     | 2.762     | 0.1405    | -0.000972 | 2.36e+03  |
# | 256       | -0.267    | 703.1     | 2.681     | 0.2686    | -0.001597 | 2.417e+03 |
# | 257       | -0.2586   | 631.5     | 1.783     | 0.29      | -0.001304 | 2.41e+03  |
# | 258       | -0.2843   | 642.0     | 4.985     | 0.1672    | -0.001354 | 2.357e+03 |
# | 259       | -0.2606   | 515.4     | 3.055     | 0.4145    | -0.000912 | 2.177e+03 |
# | 260       | -0.3298   | 659.2     | 4.416     | 0.1       | -0.002    | 2.462e+03 |
# | 261       | -0.2347   | 527.8     | 1.882     | 0.1591    | -0.000449 | 2.232e+03 |
# | 262       | -0.2471   | 463.9     | 2.359     | 0.3796    | -0.000273 | 2.207e+03 |
# | 263       | -0.2869   | 486.3     | 4.691     | 0.4984    | -0.000919 | 2.294e+03 |
# | 264       | -0.2624   | 408.7     | 2.184     | 0.2565    | -0.001298 | 2.188e+03 |
# | 265       | -0.2592   | 459.2     | 1.386     | 0.1223    | -0.001268 | 2.145e+03 |
# | 266       | -0.2485   | 395.4     | 1.401     | 0.1696    | -0.000758 | 2.236e+03 |
# | 267       | -0.2521   | 431.1     | 2.876     | 0.2592    | -0.000108 | 2.263e+03 |
# | 268       | -0.2843   | 375.3     | 4.696     | 0.2923    | -0.000915 | 2.302e+03 |
# | 269       | -0.2584   | 769.1     | 3.479     | 0.4706    | -0.000517 | 2.423e+03 |
# | 270       | -0.2774   | 405.0     | 2.571     | 0.1147    | -0.001875 | 2.11e+03  |
# | 271       | -0.286    | 491.0     | 4.094     | 0.2788    | -0.001385 | 2.243e+03 |
# | 272       | -0.2676   | 805.6     | 3.997     | 0.2615    | -0.00113  | 2.464e+03 |
# | 273       | -0.2982   | 356.0     | 4.606     | 0.2831    | -0.001169 | 2.168e+03 |
# | 274       | -0.2687   | 476.8     | 1.672     | 0.3135    | -0.001676 | 2.092e+03 |
# | 275       | -0.2723   | 751.3     | 2.808     | 0.1595    | -0.001894 | 2.478e+03 |
# | 276       | -0.2495   | 568.2     | 3.295     | 0.1074    | -0.000414 | 2.402e+03 |
# | 277       | -0.2877   | 589.0     | 4.806     | 0.2429    | -0.001457 | 2.451e+03 |
# | 278       | -0.2901   | 547.0     | 4.495     | 0.1872    | -0.001814 | 2.342e+03 |
# | 279       | -0.2802   | 522.5     | 2.863     | 0.2914    | -0.00197  | 2.414e+03 |
# | 280       | -0.2421   | 758.4     | 2.831     | 0.2539    | -0.000304 | 2.24e+03  |
# | 281       | -0.278    | 444.0     | 3.817     | 0.4375    | -0.001508 | 2.03e+03  |
# | 282       | -0.247    | 448.9     | 3.546     | 0.2655    | -0.000629 | 1.96e+03  |
# | 283       | -0.262    | 460.0     | 4.803     | 0.389     | -0.000441 | 1.907e+03 |
# | 284       | -0.2646   | 795.6     | 3.567     | 0.4487    | -0.000831 | 2.522e+03 |
# | 285       | -0.2633   | 390.3     | 4.332     | 0.3418    | -0.000579 | 1.979e+03 |
# | 286       | -0.2703   | 377.3     | 2.614     | 0.2274    | -0.001107 | 2.035e+03 |
# | 287       | -0.2489   | 398.2     | 4.123     | 0.1241    | -0.000629 | 1.899e+03 |
# | 288       | -0.2871   | 434.6     | 3.909     | 0.3696    | -0.001873 | 1.858e+03 |
# | 289       | -0.2572   | 365.6     | 2.734     | 0.2408    | -0.000915 | 1.925e+03 |
# | 290       | -0.2442   | 411.7     | 2.518     | 0.2448    | -0.000149 | 1.935e+03 |
# | 291       | -0.2943   | 373.1     | 3.367     | 0.3845    | -0.001808 | 1.852e+03 |
# | 292       | -0.2741   | 805.7     | 4.325     | 0.3932    | -0.000761 | 2.38e+03  |
# | 293       | -0.3144   | 433.0     | 1.0       | 0.1       | -0.002    | 2.33e+03  |
# | 294       | -0.2474   | 1.304e+03 | 1.329     | 0.1659    | -0.000568 | 2.149e+03 |
# | 295       | -0.2512   | 1.271e+03 | 1.561     | 0.2629    | -0.000444 | 2.088e+03 |
# | 296       | -0.2826   | 1.349e+03 | 2.563     | 0.4853    | -0.000761 | 2.12e+03  |
# | 297       | -0.2525   | 1.299e+03 | 3.875     | 0.3748    | -0.000233 | 2.036e+03 |
# | 298       | -0.3056   | 1.248e+03 | 4.372     | 0.3258    | -0.001831 | 2.027e+03 |
# | 299       | -0.2781   | 1.311e+03 | 4.474     | 0.3571    | -0.000884 | 2.08e+03  |
# | 300       | -0.313    | 854.6     | 1.951     | 0.2518    | -0.001998 | 2.51e+03  |
# | 301       | -0.2524   | 1.301e+03 | 4.436     | 0.3393    | -0.000734 | 1.974e+03 |
# | 302       | -0.2576   | 1.346e+03 | 2.542     | 0.1063    | -0.0001   | 2.005e+03 |
# | 303       | -0.2688   | 1.348e+03 | 2.708     | 0.4021    | -0.000831 | 1.941e+03 |
# | 304       | -0.2486   | 1.255e+03 | 3.843     | 0.4109    | -0.000373 | 1.929e+03 |
# | 305       | -0.2622   | 1.301e+03 | 3.042     | 0.1369    | -0.001023 | 1.909e+03 |
# | 306       | -0.2513   | 1.256e+03 | 3.024     | 0.265     | -0.000921 | 1.856e+03 |
# | 307       | -0.2793   | 1.311e+03 | 2.47      | 0.4691    | -0.00101  | 1.843e+03 |
# | 308       | -0.2501   | 1.392e+03 | 3.267     | 0.3941    | -0.000579 | 2.047e+03 |
# | 309       | -0.2517   | 1.213e+03 | 1.699     | 0.2505    | -0.000337 | 1.898e+03 |
# | 310       | -0.2635   | 1.39e+03  | 2.759     | 0.44      | -0.000211 | 1.982e+03 |
# | 311       | -0.2741   | 1.209e+03 | 4.565     | 0.4685    | -0.000977 | 1.953e+03 |
# | 312       | -0.2706   | 643.2     | 4.054     | 0.484     | -0.000586 | 2.035e+03 |
# | 313       | -0.2491   | 1.234e+03 | 3.128     | 0.2987    | -0.000818 | 1.807e+03 |
# | 314       | -0.2371   | 1.207e+03 | 1.339     | 0.1611    | -0.000465 | 1.842e+03 |
# | 315       | -0.2664   | 734.6     | 2.723     | 0.1346    | -0.001755 | 2.535e+03 |
# | 316       | -0.2688   | 1.188e+03 | 1.782     | 0.2233    | -0.001569 | 1.808e+03 |
# | 317       | -0.2528   | 1.263e+03 | 3.337     | 0.4182    | -0.000271 | 2.751e+03 |
# | 318       | -0.255    | 1.266e+03 | 3.74      | 0.2564    | -0.000771 | 2.682e+03 |
# | 319       | -0.2826   | 1.326e+03 | 2.931     | 0.4853    | -0.000803 | 2.691e+03 |
# | 320       | -0.2894   | 1.282e+03 | 3.166     | 0.3524    | -0.001571 | 2.632e+03 |
# | 321       | -0.2827   | 1.316e+03 | 2.509     | 0.4002    | -0.001549 | 2.754e+03 |
# | 322       | -0.2684   | 1.39e+03  | 1.908     | 0.4942    | -0.000236 | 1.902e+03 |
# | 323       | -0.2939   | 1.389e+03 | 4.196     | 0.2819    | -0.001878 | 1.837e+03 |
# | 324       | -0.2732   | 1.217e+03 | 4.98      | 0.2632    | -0.000910 | 2.096e+03 |
# | 325       | -0.2747   | 1.396e+03 | 1.538     | 0.4032    | -0.001359 | 2.096e+03 |
# | 326       | -0.2637   | 717.0     | 4.654     | 0.1216    | -0.000982 | 1.995e+03 |
# | 327       | -0.3476   | 1.26e+03  | 5.0       | 0.5       | -0.002    | 2.134e+03 |
# | 328       | -0.2382   | 1.148e+03 | 1.253     | 0.1501    | -0.000196 | 2.117e+03 |
# | 329       | -0.2826   | 1.144e+03 | 4.872     | 0.1984    | -0.000997 | 2.072e+03 |
# | 330       | -0.2759   | 1.224e+03 | 3.292     | 0.2076    | -0.001044 | 3.005e+03 |
# | 331       | -0.2777   | 1.151e+03 | 3.552     | 0.4584    | -0.001096 | 2.164e+03 |
# | 332       | -0.3488   | 1.06e+03  | 3.265     | 0.1522    | -0.001563 | 4.004e+03 |
# | 333       | -0.3435   | 1.17e+03  | 4.229     | 0.3692    | -0.001246 | 4.054e+03 |
# | 334       | -0.2628   | 374.4     | 4.1       | 0.2577    | -0.000537 | 2.419e+03 |
# | 335       | -0.2764   | 1.282e+03 | 2.139     | 0.4945    | -0.001375 | 1.8e+03   |
# | 336       | -0.2685   | 430.5     | 2.407     | 0.4598    | -0.001044 | 2.414e+03 |
# | 337       | -0.2794   | 352.2     | 4.899     | 0.4381    | -0.000451 | 2.357e+03 |
# | 338       | -0.3122   | 758.7     | 1.0       | 0.1       | -0.002    | 2.291e+03 |
# | 339       | -0.2586   | 1.153e+03 | 1.768     | 0.2611    | -0.001549 | 1.971e+03 |
# | 340       | -0.2963   | 1.133e+03 | 2.149     | 0.1417    | -0.001878 | 2.883e+03 |
# | 341       | -0.3612   | 1.073e+03 | 2.425     | 0.411     | -0.001965 | 4.103e+03 |
# | 342       | -0.3298   | 733.7     | 5.0       | 0.1       | -0.002    | 2.386e+03 |
# | 343       | -0.2855   | 1.321e+03 | 4.138     | 0.1224    | -0.00144  | 2.331e+03 |
# | 344       | -0.2732   | 1.036e+03 | 2.451     | 0.1907    | -0.001724 | 2.328e+03 |
# | 345       | -0.2836   | 1.169e+03 | 4.01      | 0.4082    | -0.00141  | 1.919e+03 |
# | 346       | -0.2789   | 671.5     | 1.661     | 0.4354    | -0.001759 | 2.561e+03 |
# | 347       | -0.2557   | 1.027e+03 | 2.011     | 0.4211    | -0.000815 | 2.003e+03 |
# | 348       | -0.2519   | 1.284e+03 | 1.563     | 0.2634    | -0.000358 | 2.401e+03 |
# | 349       | -0.2623   | 1.259e+03 | 4.752     | 0.4133    | -0.000279 | 2.348e+03 |
# | 350       | -0.2575   | 1.331e+03 | 1.087     | 0.4097    | -0.000655 | 2.422e+03 |
# | 351       | -0.2793   | 1.207e+03 | 4.367     | 0.1536    | -0.001275 | 2.39e+03  |
# | 352       | -0.2523   | 1.213e+03 | 3.066     | 0.2323    | -0.000241 | 2.308e+03 |
# | 353       | -0.2807   | 1.157e+03 | 4.792     | 0.1939    | -0.001263 | 2.328e+03 |
# | 354       | -0.2679   | 1.349e+03 | 1.236     | 0.3703    | -0.000752 | 2.474e+03 |
# | 355       | -0.2563   | 819.9     | 4.544     | 0.3762    | -0.0004   | 1.96e+03  |
# | 356       | -0.2809   | 1.376e+03 | 3.509     | 0.4686    | -0.001186 | 2.396e+03 |
# | 357       | -0.3002   | 1.39e+03  | 4.456     | 0.374     | -0.001694 | 2.515e+03 |
# | 358       | -0.2597   | 517.2     | 3.133     | 0.4026    | -0.000934 | 2.481e+03 |
# | 359       | -0.2437   | 537.6     | 1.896     | 0.1969    | -0.000853 | 2.535e+03 |
# | 360       | -0.2457   | 591.2     | 1.556     | 0.4718    | -0.000565 | 2.562e+03 |
# | 361       | -0.2745   | 576.1     | 4.794     | 0.2493    | -0.000177 | 2.497e+03 |
# | 362       | -0.2701   | 1.179e+03 | 3.533     | 0.4872    | -0.000249 | 2.259e+03 |
# | 363       | -0.2603   | 1.048e+03 | 2.504     | 0.1641    | -0.001523 | 2.478e+03 |
# | 364       | -0.2667   | 1.124e+03 | 4.748     | 0.3916    | -0.000726 | 2.268e+03 |
# | 365       | -0.27     | 1.095e+03 | 3.374     | 0.3185    | -0.001396 | 2.342e+03 |
# | 366       | -0.2456   | 745.7     | 3.37      | 0.1796    | -0.000482 | 2.094e+03 |
# | 367       | -0.2396   | 931.2     | 1.225     | 0.2527    | -0.000427 | 2.689e+03 |
# | 368       | -0.3      | 350.7     | 4.698     | 0.4017    | -0.00127  | 2.25e+03  |
# | 369       | -0.2926   | 1.095e+03 | 4.288     | 0.2214    | -0.001765 | 2.201e+03 |
# | 370       | -0.238    | 456.6     | 1.603     | 0.2523    | -0.000395 | 2.832e+03 |
# | 371       | -0.2494   | 471.3     | 1.829     | 0.3606    | -0.000353 | 2.878e+03 |
# | 372       | -0.2401   | 412.7     | 2.653     | 0.2319    | -0.000538 | 2.856e+03 |
# | 373       | -0.2934   | 423.6     | 2.623     | 0.1187    | -0.001849 | 2.92e+03  |
# | 374       | -0.2876   | 373.6     | 1.719     | 0.4135    | -0.001485 | 2.831e+03 |
# | 375       | -0.2571   | 510.0     | 2.536     | 0.4743    | -0.000322 | 2.841e+03 |
# | 376       | -0.2859   | 525.0     | 1.918     | 0.4718    | -0.001559 | 2.902e+03 |
# | 377       | -0.2669   | 589.0     | 3.19      | 0.4216    | -0.000203 | 2.859e+03 |
# | 378       | -0.2406   | 1.008e+03 | 2.672     | 0.2721    | -0.000990 | 1.8e+03   |
# | 379       | -0.266    | 611.7     | 3.689     | 0.335     | -0.000889 | 2.929e+03 |
# | 380       | -0.2692   | 553.6     | 2.104     | 0.3642    | -0.001047 | 2.97e+03  |
# | 381       | -0.2778   | 632.2     | 4.335     | 0.3903    | -0.000976 | 2.994e+03 |
# | 382       | -0.2568   | 487.1     | 1.384     | 0.4166    | -0.000861 | 2.986e+03 |
# | 383       | -0.3558   | 452.1     | 5.0       | 0.5       | -0.002    | 3.029e+03 |
# | 384       | -0.2766   | 577.5     | 4.204     | 0.2243    | -0.000965 | 3.041e+03 |
# | 385       | -0.2386   | 521.9     | 3.098     | 0.1237    | -0.000522 | 3.015e+03 |
# | 386       | -0.2649   | 539.0     | 1.388     | 0.381     | -0.001143 | 3.09e+03  |
# | 387       | -0.2894   | 578.6     | 3.15      | 0.1389    | -0.001396 | 3.133e+03 |
# | 388       | -0.2781   | 490.5     | 3.232     | 0.4448    | -0.001279 | 2.8e+03   |
# | 389       | -0.2422   | 676.6     | 2.667     | 0.2672    | -0.000314 | 2.919e+03 |
# | 390       | -0.2944   | 682.4     | 4.533     | 0.4444    | -0.001183 | 2.969e+03 |
# | 391       | -0.2852   | 748.0     | 1.007     | 0.1125    | -0.001624 | 2.927e+03 |
# | 392       | -0.2662   | 497.8     | 3.348     | 0.4996    | -0.000438 | 3.132e+03 |
# | 393       | -0.3104   | 523.5     | 3.132     | 0.3616    | -0.001968 | 3.19e+03  |
# | 394       | -0.2499   | 445.6     | 1.676     | 0.4216    | -0.000555 | 3.157e+03 |
# | 395       | -0.2687   | 396.6     | 2.495     | 0.1007    | -0.001154 | 3.178e+03 |
# | 396       | -0.2921   | 635.8     | 3.142     | 0.1501    | -0.001708 | 2.889e+03 |
# | 397       | -0.26     | 403.4     | 4.356     | 0.4463    | -0.000270 | 3.121e+03 |
# | 398       | -0.2891   | 446.3     | 1.921     | 0.154     | -0.001974 | 3.235e+03 |
# | 399       | -0.2798   | 488.6     | 1.207     | 0.353     | -0.001374 | 2.941e+03 |
# | 400       | -0.2559   | 550.0     | 4.45      | 0.2253    | -0.000325 | 2.819e+03 |
# | 401       | -0.3274   | 861.9     | 5.0       | 0.1       | -0.002    | 2.01e+03  |
# | 402       | -0.2946   | 367.1     | 2.983     | 0.2211    | -0.001434 | 2.887e+03 |
# | 403       | -0.2528   | 456.0     | 2.818     | 0.386     | -0.000737 | 3.109e+03 |
# | 404       | -0.2643   | 1.226e+03 | 2.561     | 0.3824    | -0.000942 | 2.632e+03 |
# | 405       | -0.2663   | 1.177e+03 | 3.309     | 0.2236    | -0.001361 | 2.614e+03 |
# | 406       | -0.3052   | 350.0     | 3.061     | 0.1378    | -0.001801 | 3.127e+03 |
# | 407       | -0.2807   | 499.8     | 1.937     | 0.1766    | -0.001627 | 3.071e+03 |
# | 408       | -0.2794   | 1.136e+03 | 1.414     | 0.2587    | -0.001876 | 2.396e+03 |
# | 409       | -0.2675   | 614.9     | 4.069     | 0.2726    | -0.000837 | 2.19e+03  |
# | 410       | -0.3064   | 1.26e+03  | 4.1       | 0.2186    | -0.001411 | 3.063e+03 |
# | 411       | -0.2863   | 367.6     | 4.293     | 0.3989    | -0.000108 | 3.241e+03 |
# | 412       | -0.4037   | 858.7     | 1.442     | 0.4475    | -0.001402 | 5.13e+03  |
# | 413       | -0.2835   | 1.319e+03 | 5.0       | 0.5       | -0.0001   | 2.185e+03 |
# | 414       | -0.2818   | 630.4     | 2.24      | 0.4839    | -0.001189 | 3.075e+03 |
# | 415       | -0.2563   | 1.397e+03 | 3.669     | 0.2376    | -0.000237 | 2.449e+03 |
# | 416       | -0.2894   | 799.2     | 1.387     | 0.3429    | -0.001656 | 2.973e+03 |
# | 417       | -0.2785   | 1.335e+03 | 3.517     | 0.4435    | -0.001123 | 2.823e+03 |
# | 418       | -0.2528   | 1.262e+03 | 3.387     | 0.2524    | -0.000489 | 2.554e+03 |
# | 419       | -0.255    | 962.6     | 3.891     | 0.4321    | -0.000438 | 2.267e+03 |
# | 420       | -0.2448   | 1.396e+03 | 1.621     | 0.1536    | -0.000368 | 2.747e+03 |
# | 421       | -0.256    | 1.384e+03 | 4.057     | 0.4513    | -0.000242 | 2.789e+03 |
# | 422       | -0.2899   | 1.387e+03 | 1.778     | 0.2739    | -0.001927 | 2.866e+03 |
# | 423       | -0.2684   | 1.375e+03 | 4.974     | 0.3355    | -0.000177 | 2.697e+03 |
# | 424       | -0.2805   | 1.348e+03 | 2.323     | 0.2569    | -0.001903 | 2.609e+03 |
# | 425       | -0.331    | 1.4e+03   | 1.0       | 0.5       | -0.002    | 2.644e+03 |
# | 426       | -0.2948   | 699.8     | 3.673     | 0.1032    | -0.001745 | 3.061e+03 |
# | 427       | -0.2507   | 898.7     | 3.434     | 0.3263    | -0.000717 | 2.255e+03 |
# | 428       | -0.2384   | 1.181e+03 | 1.068     | 0.1781    | -0.000273 | 2.015e+03 |
# | 429       | -0.2595   | 624.6     | 3.754     | 0.3467    | -0.000252 | 2.529e+03 |
# | 430       | -0.2993   | 673.3     | 2.89      | 0.3318    | -0.001693 | 3.138e+03 |
# | 431       | -0.2796   | 1.345e+03 | 2.137     | 0.1144    | -0.001846 | 2.049e+03 |
# | 432       | -0.2554   | 970.5     | 2.788     | 0.1354    | -0.000838 | 2.892e+03 |
# | 433       | -0.2914   | 1.024e+03 | 1.633     | 0.2586    | -0.00177  | 2.924e+03 |
# | 434       | -0.2971   | 948.7     | 3.136     | 0.3229    | -0.001685 | 2.929e+03 |
# | 435       | -0.2678   | 386.4     | 1.679     | 0.3805    | -0.000908 | 3.324e+03 |
# | 436       | -0.2793   | 439.7     | 1.442     | 0.4649    | -0.001421 | 3.343e+03 |
# | 437       | -0.2958   | 680.3     | 4.347     | 0.4624    | -0.001338 | 2.259e+03 |
# | 438       | -0.2691   | 375.2     | 4.448     | 0.3621    | -0.000519 | 3.389e+03 |
# | 439       | -0.2821   | 1.25e+03  | 2.047     | 0.4765    | -0.001546 | 2.294e+03 |
# | 440       | -0.313    | 395.5     | 2.797     | 0.4921    | -0.001981 | 3.446e+03 |
# | 441       | -0.2865   | 861.7     | 2.302     | 0.4538    | -0.001639 | 2.095e+03 |
# | 442       | -0.2819   | 494.7     | 4.74      | 0.4479    | -0.000202 | 3.309e+03 |
# | 443       | -0.2791   | 561.9     | 2.792     | 0.4985    | -0.000877 | 3.336e+03 |
# | 444       | -0.2696   | 873.6     | 4.87      | 0.2409    | -0.000842 | 1.935e+03 |
# | 445       | -0.2548   | 492.0     | 3.979     | 0.4091    | -0.000484 | 3.38e+03  |
# | 446       | -0.2513   | 518.4     | 1.147     | 0.2824    | -0.000963 | 3.43e+03  |
# | 447       | -0.2751   | 571.7     | 3.366     | 0.2108    | -0.001018 | 3.395e+03 |
# | 448       | -0.2946   | 514.9     | 2.105     | 0.4448    | -0.001776 | 3.488e+03 |
# | 449       | -0.253    | 579.9     | 1.223     | 0.3431    | -0.000184 | 3.455e+03 |
# | 450       | -0.2634   | 611.3     | 1.958     | 0.4098    | -0.000122 | 2.695e+03 |
# | 451       | -0.2854   | 636.4     | 3.618     | 0.4911    | -0.001177 | 3.44e+03  |
# | 452       | -0.2922   | 585.3     | 4.764     | 0.3143    | -0.001098 | 3.505e+03 |
# | 453       | -0.2537   | 641.9     | 1.218     | 0.3285    | -0.000880 | 3.374e+03 |
# | 454       | -0.3014   | 689.1     | 3.436     | 0.2384    | -0.001832 | 3.366e+03 |
# | 455       | -0.2567   | 468.9     | 4.143     | 0.3754    | -0.000426 | 3.437e+03 |
# | 456       | -0.2644   | 624.3     | 3.882     | 0.4124    | -0.000205 | 3.333e+03 |
# | 457       | -0.2292   | 665.3     | 1.459     | 0.1732    | -0.000526 | 3.289e+03 |
# | 458       | -0.26     | 705.8     | 2.685     | 0.3349    | -0.000820 | 3.291e+03 |
# | 459       | -0.2848   | 665.5     | 2.06      | 0.1935    | -0.001778 | 3.251e+03 |
# | 460       | -0.2957   | 755.6     | 2.769     | 0.3283    | -0.001816 | 3.253e+03 |
# | 461       | -0.2562   | 442.2     | 1.19      | 0.4776    | -0.000953 | 3.4e+03   |
# | 462       | -0.2737   | 593.6     | 3.493     | 0.2724    | -0.001117 | 3.268e+03 |
# | 463       | -0.2493   | 547.6     | 2.631     | 0.4151    | -0.000513 | 2.197e+03 |
# | 464       | -0.3993   | 458.1     | 1.374     | 0.2424    | -0.00159  | 4.778e+03 |
# | 465       | -0.3706   | 614.8     | 4.688     | 0.2646    | -0.000901 | 4.743e+03 |
# | 466       | -0.2694   | 933.0     | 1.697     | 0.1122    | -0.000254 | 4.894e+03 |
# | 467       | -0.3754   | 943.4     | 2.814     | 0.3317    | -0.001023 | 4.832e+03 |
# | 468       | -0.2876   | 883.1     | 4.305     | 0.3952    | -0.000447 | 4.927e+03 |
# | 469       | -0.4238   | 985.6     | 4.327     | 0.3503    | -0.001843 | 4.917e+03 |
# | 470       | -0.2889   | 1.356e+03 | 1.888     | 0.4585    | -0.001359 | 2.942e+03 |
# | 471       | -0.2689   | 788.3     | 1.313     | 0.2473    | -0.001218 | 3.329e+03 |
# | 472       | -0.2545   | 777.4     | 3.241     | 0.2193    | -0.000266 | 3.397e+03 |
# | 473       | -0.2783   | 824.8     | 1.206     | 0.1809    | -0.001379 | 3.386e+03 |
# | 474       | -0.2944   | 763.4     | 2.902     | 0.3529    | -0.001372 | 3.439e+03 |
# | 475       | -0.2548   | 852.8     | 2.614     | 0.1759    | -0.000816 | 3.324e+03 |
# | 476       | -0.2544   | 857.9     | 4.106     | 0.1961    | -0.000418 | 3.273e+03 |
# | 477       | -0.2465   | 909.6     | 2.022     | 0.2706    | -0.000245 | 3.301e+03 |
# | 478       | -0.3019   | 900.2     | 4.487     | 0.217     | -0.001726 | 3.258e+03 |
# | 479       | -0.3018   | 895.0     | 4.619     | 0.2729    | -0.001567 | 3.37e+03  |
# | 480       | -0.3141   | 981.6     | 4.161     | 0.4666    | -0.001941 | 3.322e+03 |
# | 481       | -0.2879   | 806.2     | 1.691     | 0.1082    | -0.001799 | 3.274e+03 |
# | 482       | -0.2411   | 854.1     | 1.894     | 0.2174    | -0.000513 | 3.461e+03 |
# | 483       | -0.2902   | 907.5     | 1.455     | 0.1099    | -0.001945 | 3.467e+03 |
# | 484       | -0.2633   | 809.3     | 1.72      | 0.3178    | -0.001058 | 3.493e+03 |
# | 485       | -0.3432   | 871.1     | 3.631     | 0.172     | -0.001986 | 3.52e+03  |
# | 486       | -0.2873   | 806.8     | 1.482     | 0.2301    | -0.00183  | 3.451e+03 |
# | 487       | -0.2882   | 775.7     | 2.473     | 0.288     | -0.000868 | 3.537e+03 |
# | 488       | -0.2667   | 940.2     | 3.497     | 0.1283    | -0.001229 | 2.71e+03  |
# | 489       | -0.278    | 748.1     | 1.864     | 0.1447    | -0.00144  | 3.359e+03 |
# | 490       | -0.237    | 1.039e+03 | 2.772     | 0.197     | -0.000593 | 3.457e+03 |
# | 491       | -0.2968   | 1.046e+03 | 1.331     | 0.2254    | -0.001882 | 3.499e+03 |
# | 492       | -0.3052   | 1.055e+03 | 2.396     | 0.3255    | -0.001931 | 3.396e+03 |
# | 493       | -0.2861   | 997.7     | 2.1       | 0.1177    | -0.00163  | 3.462e+03 |
# | 494       | -0.3019   | 837.5     | 2.418     | 0.1619    | -0.001963 | 3.215e+03 |
# | 495       | -0.2535   | 697.3     | 2.626     | 0.1065    | -0.001079 | 2.189e+03 |
# | 496       | -0.2642   | 1.087e+03 | 5.0       | 0.2929    | -0.000435 | 3.453e+03 |
# | 497       | -0.241    | 1.139e+03 | 2.953     | 0.293     | -0.000514 | 3.438e+03 |
# | 498       | -0.2498   | 1.188e+03 | 2.419     | 0.2547    | -0.000440 | 3.436e+03 |
# | 499       | -0.3055   | 1.163e+03 | 3.381     | 0.1763    | -0.001773 | 3.398e+03 |
# | 500       | -0.2352   | 1.155e+03 | 2.232     | 0.1055    | -0.000618 | 3.471e+03 |
# | 501       | -0.2586   | 1.243e+03 | 2.9       | 0.3021    | -0.000426 | 3.463e+03 |
# | 502       | -0.2699   | 1.189e+03 | 4.999     | 0.1581    | -0.000519 | 3.512e+03 |
# | 503       | -0.2804   | 1.235e+03 | 1.272     | 0.1979    | -0.001509 | 3.41e+03  |
# | 504       | -0.3178   | 1.136e+03 | 4.432     | 0.1721    | -0.001902 | 3.525e+03 |
# | 505       | -0.325    | 1.278e+03 | 4.869     | 0.3569    | -0.001971 | 3.496e+03 |
# | 506       | -0.3144   | 431.0     | 1.0       | 0.1       | -0.002    | 2.224e+03 |
# | 507       | -0.2757   | 744.2     | 3.968     | 0.3875    | -0.001017 | 2.037e+03 |
# | 508       | -0.2528   | 1.217e+03 | 1.851     | 0.3036    | -0.000327 | 3.567e+03 |
# | 509       | -0.3587   | 1.189e+03 | 4.416     | 0.2754    | -0.001955 | 3.604e+03 |
# | 510       | -0.3026   | 1.263e+03 | 1.607     | 0.2209    | -0.000987 | 3.602e+03 |
# | 511       | -0.2638   | 1.307e+03 | 2.363     | 0.3014    | -0.001482 | 2.578e+03 |
# | 512       | -0.2571   | 1.38e+03  | 2.838     | 0.2701    | -0.000226 | 3.019e+03 |
# | 513       | -0.255    | 1.343e+03 | 1.359     | 0.2959    | -0.000647 | 3.061e+03 |
# | 514       | -0.2995   | 1.334e+03 | 1.209     | 0.4968    | -0.001796 | 2.994e+03 |
# | 515       | -0.2651   | 1.382e+03 | 2.989     | 0.4735    | -0.000295 | 3.081e+03 |
# | 516       | -0.2833   | 1.318e+03 | 1.609     | 0.1982    | -0.001261 | 3.111e+03 |
# | 517       | -0.257    | 976.6     | 3.571     | 0.11      | -0.000205 | 1.88e+03  |
# | 518       | -0.2659   | 1.193e+03 | 2.464     | 0.4793    | -0.000330 | 3.471e+03 |
# | 519       | -0.2705   | 1.3e+03   | 3.104     | 0.4911    | -0.000397 | 3.393e+03 |
# | 520       | -0.25     | 1.297e+03 | 1.967     | 0.1755    | -0.000211 | 3.337e+03 |
# | 521       | -0.2684   | 1.356e+03 | 1.605     | 0.2018    | -0.000961 | 3.36e+03  |
# | 522       | -0.2667   | 1.267e+03 | 1.54      | 0.3242    | -0.000828 | 3.302e+03 |
# | 523       | -0.2601   | 1.315e+03 | 4.794     | 0.3904    | -0.000527 | 3.257e+03 |
# | 524       | -0.2514   | 1.341e+03 | 3.83      | 0.1836    | -0.000347 | 3.295e+03 |
# | 525       | -0.2916   | 975.5     | 4.683     | 0.3604    | -0.001266 | 2.66e+03  |
# | 526       | -0.316    | 1.38e+03  | 4.118     | 0.1919    | -0.001921 | 3.268e+03 |
# | 527       | -0.2751   | 1.27e+03  | 4.702     | 0.4893    | -0.000209 | 3.243e+03 |
# | 528       | -0.3106   | 1.229e+03 | 2.994     | 0.3369    | -0.001778 | 3.343e+03 |
# | 529       | -0.2637   | 914.4     | 4.898     | 0.2937    | -0.000500 | 2.705e+03 |
# | 530       | -0.2538   | 1.377e+03 | 1.108     | 0.3088    | -0.000437 | 3.421e+03 |
# | 531       | -0.2555   | 1.331e+03 | 3.095     | 0.3213    | -0.000208 | 3.436e+03 |
# | 532       | -0.3132   | 1.396e+03 | 2.532     | 0.4991    | -0.00179  | 3.46e+03  |
# | 533       | -0.2482   | 1.378e+03 | 3.648     | 0.1635    | -0.000427 | 3.144e+03 |
# | 534       | -0.2594   | 1.333e+03 | 4.071     | 0.3196    | -0.000180 | 3.197e+03 |
# | 535       | -0.3126   | 1.386e+03 | 2.236     | 0.3692    | -0.001932 | 3.186e+03 |
# | 536       | -0.2962   | 1.271e+03 | 2.216     | 0.2572    | -0.001592 | 3.185e+03 |
# | 537       | -0.2754   | 928.6     | 2.722     | 0.3927    | -0.001188 | 2.766e+03 |
# | 538       | -0.2964   | 690.4     | 1.685     | 0.1895    | -0.001145 | 3.527e+03 |
# | 539       | -0.2386   | 877.9     | 2.228     | 0.2007    | -0.000605 | 3.421e+03 |
# | 540       | -0.2523   | 1.199e+03 | 1.976     | 0.3637    | -0.000633 | 3.232e+03 |
# | 541       | -0.2542   | 1.17e+03  | 1.294     | 0.2611    | -0.000993 | 3.186e+03 |
# | 542       | -0.2536   | 1.154e+03 | 3.205     | 0.274     | -0.000332 | 3.245e+03 |
# | 543       | -0.2926   | 1.123e+03 | 2.523     | 0.4344    | -0.001487 | 3.211e+03 |
# | 544       | -0.2424   | 1.206e+03 | 2.264     | 0.1285    | -0.000500 | 3.277e+03 |
# | 545       | -0.2739   | 1.142e+03 | 4.017     | 0.4986    | -0.000675 | 3.298e+03 |
# | 546       | -0.3136   | 1.16e+03  | 3.107     | 0.3905    | -0.001882 | 3.121e+03 |
# | 547       | -0.2895   | 627.8     | 4.982     | 0.414     | -0.001248 | 2.579e+03 |
# | 548       | -0.2356   | 1.084e+03 | 1.403     | 0.203     | -0.000220 | 3.264e+03 |
# | 549       | -0.3044   | 1.052e+03 | 2.538     | 0.1974    | -0.001874 | 3.232e+03 |
# | 550       | -0.3072   | 1.07e+03  | 3.415     | 0.4529    | -0.00177  | 3.324e+03 |
# =====================================================================================

# %%
print(Boptimizer.max)
solution = Boptimizer.max['params']
print(solution)
# Out:
# {'target': -0.22876529395580292, 'params': {'ai': 1070.272701836348, 'c1': 1.486832781708833, 'coef': 0.16582847807443762, 'dmpdz': -0.000532085103603181, 'tau': 2007.4436688432652}}
# {'ai': 1070.272701836348, 'c1': 1.486832781708833, 'coef': 0.16582847807443762, 'dmpdz': -0.000532085103603181, 'tau': 2007.4436688432652}

# %%
ice_sed_ai = 390.818 
clubb_c1 = 1.624
clubb_gamma_coef = 0.179
zmconv_dmpdz = -0.000601
zmconv_tau = 2687.888


#ice_sed_ai =443.223
#clubb_c1 = 1.174
#clubb_gamma_coef = 0.156
#zmconv_tau = 2227.011
#zmconv_dmpdz = -0.000659
 

para = np.array([ice_sed_ai,clubb_c1,clubb_gamma_coef,zmconv_tau,zmconv_dmpdz]).reshape(1,-1)

mm.validate(para)
# Out:
# [[ 3.908180e+02  1.624000e+00  1.790000e-01  2.687888e+03 -6.010000e-04]]
# No normalization LWCF=4.602 PRECT=0.886
# normalization LWCF=0.870 PRECT=0.994

# %%
print(Boptimizer.res[328])
# Out:
# {'target': -1.9404135942459106, 'params': {'ai': 480.0067262455701, 'c1': 2.027190984304075, 'coef': 0.11965934099507734, 'dmpdz': -0.0004934991326674071, 'tau': 2641.601527876257}}

# %%
data = np.zeros((1,5))
for i,v in enumerate(solution):
    data[0,i] = solution[v]
    
data = np.array([506.7,3.744,0.1292,-0.000254,2.313e+03]).reshape(1,-1)
#data = np.array([1360.25,1.13,0.265,-0.00049,4049.74]).reshape(1,-1)
data = np.array([500,1.335,0.32,-0.7e-3, 3600]).reshape(1,-1)
pred_y = reg.predict(data)
print(pred_y)
# Out:
# [5.293064]

# %% [markdown]
# ## nelder mead

# %%
def fun2(X):
    X = X.reshape(1,-1)
    pred_y = reg.predict(X) + reg1.predict(X)
    return pred_y

# %%
x0 = np.array([500, 1.335, 0.32, 3600, -0.7e-3])
x0 = np.array([686.4, 3.904, 0.1895, 2.152e+03,-0.000366])

res = minimize(fun2, x0, method='nelder-mead',
               options={'xatol': 1e-8, 'disp': True, 'return_all':True})
# Out:
# Optimization terminated successfully.
#          Current function value: 1.950389
#          Iterations: 55
#          Function evaluations: 273

# %%
print(res)
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 5.946317195892334
#              x: [ 6.950e+02  4.135e+00  1.831e-01  2.151e+03 -3.724e-04]
#            nit: 50
#           nfev: 255
#  final_simplex: (array([[ 6.950e+02,  4.135e+00, ...,  2.151e+03,
#                         -3.724e-04],
#                        [ 6.950e+02,  4.135e+00, ...,  2.151e+03,
#                         -3.724e-04],
#                        ...,
#                        [ 6.950e+02,  4.135e+00, ...,  2.151e+03,
#                         -3.724e-04],
#                        [ 6.950e+02,  4.135e+00, ...,  2.151e+03,
#                         -3.724e-04]]), array([ 5.946e+00,  5.946e+00,  5.946e+00,  5.946e+00,
#                         5.946e+00,  5.946e+00]))
#        allvecs: [array([ 6.864e+02,  3.904e+00,  1.895e-01,  2.152e+03,
#                        -3.660e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 7.001e+02,  3.982e+00,  1.800e-01,  2.195e+03,
#                        -3.733e-04]), array([ 6.965e+02,  4.076e+00,  1.875e-01,  2.133e+03,
#                        -3.751e-04]), array([ 6.965e+02,  4.076e+00,  1.875e-01,  2.133e+03,
#                        -3.751e-04]), array([ 6.965e+02,  4.076e+00,  1.875e-01,  2.133e+03,
#                        -3.751e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04]), array([ 6.950e+02,  4.135e+00,  1.831e-01,  2.151e+03,
#                        -3.724e-04])]

# %%
data = np.array([ 6.864e+02,4.099e+00,1.895e-01,2.152e+03,-3.660e-04]).reshape(1,-1)
pred_y = reg.predict(data)
print(pred_y)
# Out:
# [0.9015588]

# %% [markdown]
# ## Multi-objective tuning

# %%
import numpy as np
from pymoo.core.problem import ElementwiseProblem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize

# %%
class MyProblem(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var=5,
                         n_obj=2,
                         #n_ieq_constr=2,
                         xl=np.array([350,1.0,0.1,1800,-2.0e-3]),
                         xu=np.array([1400,5.0,0.5,14400,-0.1e-3]))

    def _evaluate(self, x, out, *args, **kwargs):
        x = x.reshape(1,-1)
        f1 = mm.reg1.predict(x)
        f2 = mm.reg2.predict(x)

        out["F"] = [f1, f2]


xl = np.array([350,1.0,0.1,1800,-2.0e-3])
xu = np.array([1400,5.0,0.5,14400,-0.1e-3])
problem = MyProblem()

# %%
algorithm = NSGA2(pop_size=100)
res = minimize(problem,
               algorithm,
               ('n_gen', 200),
               seed=1,
               verbose=True)
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |      100 |      5 |             - |             -
#      2 |      200 |      4 |  0.3187473267 |         ideal
#      3 |      300 |      2 |  2.8699617155 |         ideal
#      4 |      400 |      4 |  0.1998069552 |         ideal
#      5 |      500 |      6 |  0.0750145969 |         ideal
#      6 |      600 |      7 |  0.0875118523 |         ideal
#      7 |      700 |      9 |  0.1343423066 |         ideal
#      8 |      800 |     10 |  0.0349262088 |             f
#      9 |      900 |     11 |  0.0735192780 |         ideal
#     10 |     1000 |     15 |  0.0329840218 |         ideal
#     11 |     1100 |     17 |  0.0892172335 |         ideal
#     12 |     1200 |     19 |  0.1366592621 |         nadir
#     13 |     1300 |     15 |  0.0030939456 |         ideal
#     14 |     1400 |     15 |  0.0127960250 |         ideal
#     15 |     1500 |     16 |  0.0529762535 |         ideal
#     16 |     1600 |     19 |  0.0094622711 |             f
#     17 |     1700 |     21 |  0.0142146231 |             f
#     18 |     1800 |     27 |  0.0095164050 |             f
#     19 |     1900 |     26 |  0.0144738474 |         nadir
#     20 |     2000 |     31 |  0.0028250466 |             f
#     21 |     2100 |     29 |  0.0318362807 |         nadir
#     22 |     2200 |     29 |  0.0083827089 |         ideal
#     23 |     2300 |     27 |  0.0000332683 |             f
#     24 |     2400 |     37 |  0.0026750426 |             f
#     25 |     2500 |     48 |  0.0016049617 |             f
#     26 |     2600 |     50 |  0.2419452504 |         nadir
#     27 |     2700 |     59 |  0.0011937685 |             f
#     28 |     2800 |     70 |  0.0010699698 |             f
#     29 |     2900 |     62 |  0.0016907476 |             f
#     30 |     3000 |     68 |  0.0035466479 |             f
#     31 |     3100 |     79 |  0.0000166079 |             f
#     32 |     3200 |     76 |  0.0003262045 |             f
#     33 |     3300 |     82 |  0.0026032748 |         ideal
#     34 |     3400 |     53 |  0.0000540466 |             f
#     35 |     3500 |     49 |  0.2301501198 |         nadir
#     36 |     3600 |     56 |  0.0000840265 |             f
#     37 |     3700 |     55 |  0.0009086231 |             f
#     38 |     3800 |     62 |  0.0008332471 |             f
#     39 |     3900 |     70 |  0.0010532850 |             f
#     40 |     4000 |     72 |  0.0014069313 |             f
#     41 |     4100 |     88 |  0.0019965616 |             f
#     42 |     4200 |    100 |  0.0024713309 |             f
#     43 |     4300 |    100 |  0.0022145381 |             f
#     44 |     4400 |    100 |  0.0023025442 |             f
#     45 |     4500 |    100 |  0.0024824171 |             f
#     46 |     4600 |    100 |  0.0022680243 |             f
#     47 |     4700 |    100 |  0.0020843937 |             f
#     48 |     4800 |    100 |  0.0020624383 |             f
#     49 |     4900 |    100 |  0.0026350994 |             f
#     50 |     5000 |    100 |  0.000000E+00 |             f
#     51 |     5100 |    100 |  0.1948115268 |         nadir
#     52 |     5200 |    100 |  4.359636E-06 |             f
#     53 |     5300 |    100 |  4.359636E-06 |             f
#     54 |     5400 |    100 |  0.0001264493 |             f
#     55 |     5500 |    100 |  0.0001308089 |             f
#     56 |     5600 |    100 |  0.0002485390 |             f
#     57 |     5700 |    100 |  0.0002528986 |             f
#     58 |     5800 |    100 |  0.0003749883 |             f
#     59 |     5900 |    100 |  0.0001403405 |             f
#     60 |     6000 |    100 |  0.0001403405 |             f
#     61 |     6100 |    100 |  0.0002501636 |             f
#     62 |     6200 |    100 |  0.0003380618 |             f
#     63 |     6300 |    100 |  0.0004653234 |             f
#     64 |     6400 |    100 |  0.0004784023 |             f
#     65 |     6500 |    100 |  0.0005532216 |             f
#     66 |     6600 |    100 |  0.0015411406 |             f
#     67 |     6700 |    100 |  0.0015589471 |             f
#     68 |     6800 |    100 |  0.0027221800 |             f
#     69 |     6900 |    100 |  0.000000E+00 |             f
#     70 |     7000 |    100 |  0.000000E+00 |             f
#     71 |     7100 |    100 |  0.000000E+00 |             f
#     72 |     7200 |    100 |  0.000000E+00 |             f
#     73 |     7300 |    100 |  0.000000E+00 |             f
#     74 |     7400 |    100 |  0.000000E+00 |             f
#     75 |     7500 |    100 |  0.000000E+00 |             f
#     76 |     7600 |    100 |  0.000000E+00 |             f
#     77 |     7700 |    100 |  0.000000E+00 |             f
#     78 |     7800 |    100 |  0.000000E+00 |             f
#     79 |     7900 |    100 |  0.000000E+00 |             f
#     80 |     8000 |    100 |  0.000000E+00 |             f
#     81 |     8100 |    100 |  0.000000E+00 |             f
#     82 |     8200 |    100 |  0.000000E+00 |             f
#     83 |     8300 |    100 |  0.000000E+00 |             f
#     84 |     8400 |    100 |  0.000000E+00 |             f
#     85 |     8500 |    100 |  0.000000E+00 |             f
#     86 |     8600 |    100 |  0.0095883668 |         nadir
#     87 |     8700 |    100 |  0.000000E+00 |             f
#     88 |     8800 |    100 |  0.000000E+00 |             f
#     89 |     8900 |    100 |  0.000000E+00 |             f
#     90 |     9000 |    100 |  0.000000E+00 |             f
#     91 |     9100 |    100 |  0.000000E+00 |             f
#     92 |     9200 |    100 |  0.000000E+00 |             f
#     93 |     9300 |    100 |  0.0000959936 |             f
#     94 |     9400 |    100 |  0.0000959936 |             f
#     95 |     9500 |    100 |  0.0000959936 |             f
#     96 |     9600 |    100 |  0.0000959936 |             f
#     97 |     9700 |    100 |  0.0000959936 |             f
#     98 |     9800 |    100 |  0.0000959936 |             f
#     99 |     9900 |    100 |  0.0000959936 |             f
#    100 |    10000 |    100 |  0.0000959936 |             f
#    101 |    10100 |    100 |  0.0000959936 |             f
#    102 |    10200 |    100 |  0.1173985550 |         nadir
#    103 |    10300 |    100 |  0.000000E+00 |             f
#    104 |    10400 |    100 |  0.000000E+00 |             f
#    105 |    10500 |    100 |  0.000000E+00 |             f
#    106 |    10600 |    100 |  0.000000E+00 |             f
#    107 |    10700 |    100 |  0.000000E+00 |             f
#    108 |    10800 |    100 |  0.000000E+00 |             f
#    109 |    10900 |    100 |  0.000000E+00 |             f
#    110 |    11000 |    100 |  0.000000E+00 |             f
#    111 |    11100 |    100 |  0.000000E+00 |             f
#    112 |    11200 |    100 |  0.000000E+00 |             f
#    113 |    11300 |    100 |  0.000000E+00 |             f
#    114 |    11400 |    100 |  0.000000E+00 |             f
#    115 |    11500 |    100 |  0.000000E+00 |             f
#    116 |    11600 |    100 |  0.000000E+00 |             f
#    117 |    11700 |    100 |  0.000000E+00 |             f
#    118 |    11800 |    100 |  0.000000E+00 |             f
#    119 |    11900 |    100 |  0.000000E+00 |             f
#    120 |    12000 |    100 |  0.000000E+00 |             f
#    121 |    12100 |    100 |  0.000000E+00 |             f
#    122 |    12200 |    100 |  0.000000E+00 |             f
#    123 |    12300 |    100 |  0.000000E+00 |             f
#    124 |    12400 |    100 |  0.000000E+00 |             f
#    125 |    12500 |    100 |  0.000000E+00 |             f
#    126 |    12600 |    100 |  0.000000E+00 |             f
#    127 |    12700 |    100 |  0.000000E+00 |             f
#    128 |    12800 |    100 |  0.000000E+00 |             f
#    129 |    12900 |    100 |  0.000000E+00 |             f
#    130 |    13000 |    100 |  0.000000E+00 |             f
#    131 |    13100 |    100 |  0.000000E+00 |             f
#    132 |    13200 |    100 |  0.000000E+00 |             f
#    133 |    13300 |    100 |  0.000000E+00 |             f
#    134 |    13400 |    100 |  0.000000E+00 |             f
#    135 |    13500 |    100 |  0.000000E+00 |             f
#    136 |    13600 |    100 |  0.0003215761 |             f
#    137 |    13700 |    100 |  0.0003215761 |             f
#    138 |    13800 |    100 |  0.0006431523 |             f
#    139 |    13900 |    100 |  0.0009647284 |             f
#    140 |    14000 |    100 |  0.0012863045 |             f
#    141 |    14100 |    100 |  0.0012863045 |             f
#    142 |    14200 |    100 |  0.0012863045 |             f
#    143 |    14300 |    100 |  0.0009647284 |             f
#    144 |    14400 |    100 |  0.0009647284 |             f
#    145 |    14500 |    100 |  0.0009647284 |             f
#    146 |    14600 |    100 |  0.0006431523 |             f
#    147 |    14700 |    100 |  0.0006431523 |             f
#    148 |    14800 |    100 |  0.0006431523 |             f
#    149 |    14900 |    100 |  0.0006431523 |             f
#    150 |    15000 |    100 |  0.0006431523 |             f
#    151 |    15100 |    100 |  0.0009647284 |             f
#    152 |    15200 |    100 |  0.0006431523 |             f
#    153 |    15300 |    100 |  0.0009647284 |             f
#    154 |    15400 |    100 |  0.0009647284 |             f
#    155 |    15500 |    100 |  0.0006431523 |             f
#    156 |    15600 |    100 |  0.0006431523 |             f
#    157 |    15700 |    100 |  0.0009647284 |             f
#    158 |    15800 |    100 |  0.0009647284 |             f
#    159 |    15900 |    100 |  0.0006431523 |             f
#    160 |    16000 |    100 |  0.0009647284 |             f
#    161 |    16100 |    100 |  0.0009647284 |             f
#    162 |    16200 |    100 |  0.0012863045 |             f
#    163 |    16300 |    100 |  0.0009647284 |             f
#    164 |    16400 |    100 |  0.0009647284 |             f
#    165 |    16500 |    100 |  0.0012863045 |             f
#    166 |    16600 |    100 |  0.0009647284 |             f
#    167 |    16700 |    100 |  0.0006431523 |             f
#    168 |    16800 |    100 |  0.0006431523 |             f
#    169 |    16900 |    100 |  0.0006431523 |             f
#    170 |    17000 |    100 |  0.0006431523 |             f
#    171 |    17100 |    100 |  0.0009647284 |             f
#    172 |    17200 |    100 |  0.1479133528 |         nadir
#    173 |    17300 |    100 |  0.0002784773 |             f
#    174 |    17400 |    100 |  0.0002784773 |             f
#    175 |    17500 |    100 |  0.0002784773 |             f
#    176 |    17600 |    100 |  0.0002784773 |             f
#    177 |    17700 |    100 |  0.0005569546 |             f
#    178 |    17800 |    100 |  0.0008354318 |             f
#    179 |    17900 |    100 |  0.0005569546 |             f
#    180 |    18000 |    100 |  0.0005569546 |             f
#    181 |    18100 |    100 |  0.0072633347 |         nadir
#    182 |    18200 |    100 |  0.000000E+00 |             f
#    183 |    18300 |    100 |  0.000000E+00 |             f
#    184 |    18400 |    100 |  0.000000E+00 |             f
#    185 |    18500 |    100 |  0.000000E+00 |             f
#    186 |    18600 |    100 |  0.000000E+00 |             f
#    187 |    18700 |    100 |  0.000000E+00 |             f
#    188 |    18800 |    100 |  0.000000E+00 |             f
#    189 |    18900 |    100 |  0.000000E+00 |             f
#    190 |    19000 |    100 |  0.000000E+00 |             f
#    191 |    19100 |    100 |  0.000000E+00 |             f
#    192 |    19200 |    100 |  0.000000E+00 |             f
#    193 |    19300 |    100 |  0.000000E+00 |             f
#    194 |    19400 |    100 |  0.000000E+00 |             f
#    195 |    19500 |    100 |  0.000000E+00 |             f
#    196 |    19600 |    100 |  0.000000E+00 |             f
#    197 |    19700 |    100 |  0.000000E+00 |             f
#    198 |    19800 |    100 |  0.000000E+00 |             f
#    199 |    19900 |    100 |  0.000000E+00 |             f
#    200 |    20000 |    100 |  3.126241E-07 |             f

# %%
X = res.X
F = res.F

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))

for index in np.arange(F.shape[0]):
    if index%4 == 0:
        va = 'bottom'
        ha = 'left'
    elif index%4 == 1:
        va = 'top'
        ha = 'right'
    elif index%4 == 2:
        va = 'top'
        ha = 'left'
    axes.text(F[index,0],F[index,1],index,fontsize=8,va=va,ha=ha)

axes.scatter(F[:, 0], F[:, 1], s=50, facecolors='none', edgecolors='blue')
axes.set_xlabel('RMSE of PRECT')
axes.set_ylabel('RMSE of LWCF')
# Out:
# Text(0, 0.5, 'RMSE of LWCF')

# %%
#print(F)
np.set_printoptions(suppress=True)
print(X)
# Out:
# [[ 582.56927525    2.9514445     0.18536478 1965.97684016   -0.00060748]
#  [ 443.22344366    1.17383528    0.15597974 2227.01120773   -0.00065787]
#  [ 493.91612301    2.9153425     0.17954714 2128.30367682   -0.00060542]
#  [ 508.97630969    1.16992653    0.18028409 2129.52062565   -0.00065764]
#  [ 493.75764669    3.76218657    0.18203139 2125.43358038   -0.00060542]
#  [ 581.56838154    2.16575172    0.1803563  1967.1428796    -0.00058714]
#  [ 443.96240191    2.94800248    0.17957432 2118.01187971   -0.0004032 ]
#  [ 443.97177476    1.17383535    0.18084642 2227.01120773   -0.00065787]
#  [ 443.44380505    1.17383387    0.15612625 1968.16127806   -0.00065787]
#  [ 444.21681216    2.94168492    0.17991859 2026.21144785   -0.00058424]
#  [ 443.22751661    2.9531787     0.14521766 2008.86425594   -0.00058792]
#  [ 443.44380505    1.17383387    0.17955839 2127.54569008   -0.00065787]
#  [ 508.97630969    1.16992653    0.15666595 2129.52062565   -0.00065764]
#  [ 462.98480498    1.10782051    0.17666936 2030.73853875   -0.00065771]
#  [ 462.87849276    2.94480986    0.17813012 2030.50481313   -0.00058793]
#  [ 401.0568125     1.17199859    0.17998146 2133.16104093   -0.0006577 ]
#  [ 493.76080425    2.95106906    0.1564129  2026.16689785   -0.00058822]
#  [ 493.46913656    3.44096479    0.17993987 1953.41708396   -0.00060508]
#  [ 401.0568125     2.18496573    0.17998146 2132.11870764   -0.0005837 ]
#  [ 400.93707779    2.92118672    0.17992938 2008.70327146   -0.00058426]
#  [ 426.03729564    1.17382336    0.18026724 1989.53370195   -0.00065766]
#  [ 444.21681216    2.12876029    0.17991859 2012.49001438   -0.00058425]
#  [ 443.27866914    1.61973268    0.17933421 1956.59698666   -0.00049021]
#  [ 401.0568125     1.57397828    0.17927419 1963.86105867   -0.0005837 ]
#  [ 443.27866914    1.61184354    0.17810574 2119.35906988   -0.00058438]
#  [ 446.47197944    2.1805565     0.17986846 1968.681063     -0.00038273]
#  [ 444.27261484    1.59621251    0.17960127 2033.18401448   -0.00039805]
#  [ 444.1856236     2.94168492    0.17990847 2026.44868293   -0.00058424]
#  [ 443.24190209    2.94703309    0.17809236 2036.0173993    -0.0005844 ]
#  [ 444.18983401    2.91735725    0.14649381 2037.97868808   -0.00058853]
#  [ 444.16114222    1.60117326    0.178116   2126.85865792   -0.0005844 ]
#  [ 443.50095134    1.59621251    0.1796029  2035.57110228   -0.00057873]
#  [ 493.76080425    2.95106906    0.1564129  2028.41815538   -0.00060651]
#  [ 492.95550976    3.44096479    0.17993987 1953.41708396   -0.00060508]
#  [ 444.21681216    2.12876029    0.17998129 2008.00398751   -0.0005841 ]
#  [ 581.56838154    2.14688507    0.1803563  1967.1428796    -0.00058714]
#  [ 443.8044113     2.94558533    0.17958129 2021.16285599   -0.0004032 ]
#  [ 493.91612301    2.91244766    0.17954714 2128.30367682   -0.00060542]
#  [ 443.99513149    1.1738367     0.15597974 2227.01120773   -0.00065787]
#  [ 444.30241657    2.17718528    0.18002115 1968.1790135    -0.00058714]
#  [ 462.87849276    2.94480986    0.17987037 2036.16234869   -0.00058793]
#  [ 508.97630969    1.16992653    0.15604163 2129.52062565   -0.00065758]
#  [ 445.08131378    1.17383371    0.17995987 2083.14664218   -0.00065787]
#  [ 492.95550976    3.42534203    0.17993987 1953.41708396   -0.00058441]
#  [ 443.82301896    1.17380669    0.17996936 2118.97947984   -0.00065787]
#  [ 443.44339355    2.94545011    0.14348912 2015.11660026   -0.00058582]
#  [ 462.87849276    2.94480986    0.17987037 2033.0830199    -0.00058793]
#  [ 443.22344366    1.17383528    0.18023923 2214.49445919   -0.00065762]
#  [ 451.01370522    2.95300023    0.17813012 2009.07456563   -0.00058793]
#  [ 443.22751661    2.95335561    0.15156106 2039.66339104   -0.00058688]
#  [ 443.52702572    2.94545011    0.14771812 1960.83244953   -0.00058562]
#  [ 492.92125758    3.77123543    0.17952427 2063.86110828   -0.00060382]
#  [ 443.22751661    2.95335561    0.17990964 2144.91287898   -0.00058688]
#  [ 444.22505933    1.59621251    0.17960127 2033.2096464    -0.0004032 ]
#  [ 449.02825479    2.95106906    0.15606658 2026.16689785   -0.00058735]
#  [ 425.39884566    1.17382336    0.18026724 1985.74894633   -0.00065766]
#  [ 492.95550976    2.93173213    0.17993987 2091.55662739   -0.00060351]
#  [ 463.23416868    2.9419452     0.17987346 2036.16234869   -0.00060461]
#  [ 493.75167731    3.76247671    0.18203139 2128.57028752   -0.00060542]
#  [ 491.90430228    3.77123543    0.17951862 2072.082547     -0.00060382]
#  [ 444.6272993     2.1661706     0.18093256 2008.9726661    -0.0005878 ]
#  [ 446.39644866    1.1738367     0.18158687 2225.17644872   -0.00065787]
#  [ 445.29636831    2.91823446    0.17989965 2009.66286467   -0.00041569]
#  [ 443.22751661    2.9203292     0.14827415 2039.12711115   -0.00060741]
#  [ 444.62749799    2.92143175    0.17961025 2012.47304965   -0.0005878 ]
#  [ 493.80993599    2.95106666    0.17776969 2028.85962094   -0.00058399]
#  [ 446.02313314    2.9503011     0.17987037 2033.0830199    -0.00058112]
#  [ 442.58201907    2.94180204    0.17987346 2008.51114968   -0.00060461]
#  [ 443.43235297    2.94541757    0.14506901 2031.09201066   -0.00058853]
#  [ 444.21681216    2.12876029    0.17991859 2013.11535967   -0.00058425]
#  [ 492.9533812     3.44096479    0.17993987 1954.72536662   -0.00060508]
#  [ 493.76080425    2.94470675    0.1770176  2024.49069636   -0.00058821]
#  [ 444.21681216    2.12876029    0.17998129 2031.96682189   -0.0005841 ]
#  [ 494.51329585    3.43043839    0.17993127 1962.9248655    -0.00058766]
#  [ 401.0568125     1.57397828    0.18025371 1961.14024152   -0.00058409]
#  [ 444.30241657    2.92179686    0.17724092 1968.1790135    -0.00058714]
#  [ 493.80956374    2.95111181    0.17762874 1968.96618231   -0.00058432]
#  [ 493.55189412    2.91459846    0.17869172 2122.28967933   -0.00060445]
#  [ 443.50970712    2.95348093    0.14889158 2065.45583044   -0.00058747]
#  [ 443.22751661    2.9531787     0.14827415 2039.12711115   -0.00060741]
#  [ 462.41622061    2.9503011     0.17987037 2033.0830199    -0.00058796]
#  [ 493.43488438    3.77123543    0.17954714 1987.79047445   -0.00060529]
#  [ 493.76080425    2.95106906    0.17825922 2026.16689785   -0.00058822]
#  [ 579.54686139    2.9514445     0.18536478 1965.97684016   -0.00060748]
#  [ 443.22751661    2.9531787     0.14521766 2008.71575267   -0.00058795]
#  [ 492.39900318    2.93693937    0.17954714 2128.30367682   -0.00060498]
#  [ 443.51065621    2.94800248    0.14787942 2118.01187971   -0.00058183]
#  [ 493.44085376    3.7709453     0.17954714 1984.65376732   -0.00060529]
#  [ 444.21681216    2.12876029    0.17992946 2132.11517543   -0.00058375]
#  [ 495.28836126    2.94480986    0.17813012 2030.50481313   -0.00058799]
#  [ 443.24190209    2.94703017    0.17811453 1962.26459614   -0.00058715]
#  [ 444.30241657    2.94272769    0.1773728  1968.1790135    -0.00058714]
#  [ 493.80956374    2.95111181    0.17964411 1969.28284929   -0.00058432]
#  [ 425.13265976    1.17382336    0.18026724 1989.12959117   -0.00065766]
#  [ 493.75764669    3.77142206    0.18235906 2125.43358038   -0.00060542]
#  [ 401.0568125     1.59153491    0.17927419 1963.86105867   -0.00060644]
#  [ 493.46913656    3.74523593    0.18087751 1953.41708396   -0.00060697]
#  [ 445.00870215    2.94168492    0.17990847 2026.44868293   -0.00058424]
#  [ 443.54850685    1.59621251    0.1796029  2035.54873305   -0.00057873]
#  [ 400.93707779    2.92129982    0.17992938 2008.70327146   -0.00058426]]

# %%
### ai     |    c1     |   coef    |   dmpdz   |    tau    |

# %%
[ice_sed_ai,clubb_c1,clubb_gamma_coef,zmconv_tau,zmconv_dmpdz]
# Out:
# [390.818, 1.624, 0.179, 2687.888, -0.000601]

# %%
train_x_extra = np.array([[390.818, 1.624, 0.179, 2687.888, -0.000601]
])
train_y_extra = np.array([[4.737,0.92],
                          [5.149,0.918],
                          [4.885,0.915],
                          [4.703,0.947]
])
prect_y_extra = np.array([[4.602,0.886],
                          [4.80,0.90],
                          [4.640,0.895],
                          [4.702,0.887]
])

# %%
train_y
# Out:
#              PRECT    SWCF    LWCF    FLUT  FSNTOA
# workdir.1    1.646  14.072  10.549  11.766  13.770
# workdir.2    1.740  17.915  12.247  13.726  17.554
# workdir.3    1.756  18.222  11.825  13.269  17.986
# workdir.4    1.458  14.202   8.064   8.114  13.848
# workdir.5    0.957   9.648   6.187   6.023   9.200
# ...            ...     ...     ...     ...     ...
# workdir.196  1.741  17.671  11.971  13.458  17.332
# workdir.197  1.034   9.732   6.230   5.949   9.221
# workdir.198  1.701  16.847  11.188  12.454  16.546
# workdir.199  0.945  10.036   5.808   5.922   9.576
# workdir.200  1.379  13.191   8.417   8.559  12.881
#
# [200 rows x 5 columns]

# %%
train_y_extra[:,0]
# Out:
# array([4.737, 5.149])

# %%
reg = xgb.XGBRegressor(n_estimators=600, nthread=8, max_depth=7) 
fig, ax = plt.subplots(1,2,figsize=(9,4))

ref = [5.29,0.891]

for k,m in enumerate(['LWCF','PRECT']):
    print(m)
    reg.fit(train_x, train_y.loc[:,m])
    pred = reg.predict(test_x)
    #rmse = mean_squared_error(test_y.loc[:,m], pred, squared=False)
    score = reg.score(test_x,test_y.loc[:,m])
    #print(f'{m}=\t\t\t\t{score:.2f}')

    ax[k].scatter(test_y.loc[:,m]/ref[k],pred/ref[k])
    ax[k].set_title(f'{m}, $R^2$={score:.2f}')
    #ax[k].set_xlim([np.min(pred)*0.90,np.max(pred)*1.05])
    #ax[k].set_ylim([np.min(pred)*0.90,np.max(pred)*1.05])
    ax[k].plot([0,1],[0,1], transform=ax[k].transAxes, color='k')
    ax[k].set_xlabel('Model')
    ax[k].set_ylabel('Surrogate Model')
    

    
    ax[k].scatter(train_y_extra[:,k]/ref[k],prect_y_extra[:,k]/ref[k],color='#FE9A84')
    
    #ax[0].scatter(4.929,5.29,marker='*',color='r')
    #ax[1].scatter(0.923,0.891,marker='*',color='r')
      
plt.tight_layout()
# Out:
# LWCF
# PRECT

# %% [markdown]
# ## Turbo

# %%
class Levy:
    def __init__(self, dim=10):
        self.dim = dim
        self.lb = -5 * np.ones(dim)
        self.ub = 10 * np.ones(dim)
        
    def __call__(self, x):
        assert len(x) == self.dim
        assert x.ndim == 1
        assert np.all(x <= self.ub) and np.all(x >= self.lb)
        w = 1 + (x - 1.0) / 4.0
        val = np.sin(np.pi * w[0]) ** 2 + \
            np.sum((w[1:self.dim - 1] - 1) ** 2 * (1 + 10 * np.sin(np.pi * w[1:self.dim - 1] + 1) ** 2)) + \
            (w[self.dim - 1] - 1) ** 2 * (1 + np.sin(2 * np.pi * w[self.dim - 1])**2)
        
        print(val.shape)
        return val

f = Levy(10)

# %%
class E3SM:
    def __init__(self, dim=5):
        self.dim = dim
        self.lb = np.array([350,1.0,0.1,1800,-2.0e-3])
        #self.ub = np.array([1400,5.0,0.5,14400,-0.1e-3])
        self.ub = np.array([1400,5.0,0.5,5000,-0.1e-3])
        
    def __call__(self, x):
        x = x.reshape(1,-1)
        val = mm.cost_fun3(x)[0]
        return val

f = E3SM()

# %%
turbo1 = Turbo1(
    f=f,  # Handle to objective function
    lb=f.lb,  # Numpy array specifying lower bounds
    ub=f.ub,  # Numpy array specifying upper bounds
    n_init=20,  # Number of initial bounds from an Latin hypercube design
    max_evals = 1000,  # Maximum number of evaluations
    batch_size=10,  # How large batch size TuRBO uses
    verbose=True,  # Print information from each batch
    use_ard=True,  # Set to true if you want to use ARD for the GP kernel
    max_cholesky_size=2000,  # When we switch from Cholesky to Lanczos
    n_training_steps=50,  # Number of steps of ADAM to learn the hypers
    min_cuda=1024,  # Run on the CPU for small datasets
    device="cpu",  # "cpu" or "cuda"
    dtype="float64",  # float64 or float32
)

turbo1.optimize()
# Out:
# Using dtype = torch.float64
# Using device = cpu
# Starting from fbest = 0.2357
# 40) New best: 0.231
# 60) New best: 0.2294
# 70) New best: 0.2271
# 120) Restarting with fbest = 0.2271
# Starting from fbest = 0.2364
# 290) Restarting with fbest = 0.2274
# Starting from fbest = 0.2506
# 410) New best: 0.226
# 440) Restarting with fbest = 0.226
# Starting from fbest = 0.2462
# 550) Restarting with fbest = 0.2314
# Starting from fbest = 0.2427
# 640) New best: 0.2258
# 670) New best: 0.2247
# 690) Restarting with fbest = 0.2247
# Starting from fbest = 0.2507
# 810) Restarting with fbest = 0.2309
# Starting from fbest = 0.2439
# 960) Restarting with fbest = 0.2276
# Starting from fbest = 0.2363

# %%
X = turbo1.X  # Evaluated points
fX = turbo1.fX  # Observed values
ind_best = np.argmin(fX)
f_best, x_best = fX[ind_best], X[ind_best, :]

print(f'Best value = {f_best} at the iteration {ind_best}')
print(f'Best parameter = {x_best}')

for i in range(len(p_names)):
    print(f'{p_names[i]} \t = {x_best[i]:.4e}')
# Out:
# Best value = [0.22471981] at the iteration 661
# Best parameter = [ 4.39422748e+02  1.46795069e+00  1.73370698e-01  2.68202257e+03
#  -3.87788808e-04]
# ice_sed_ai 	 = 4.3942e+02
# clubb_c1 	 = 1.4680e+00
# clubb_gamma_coef 	 = 1.7337e-01
# zmconv_tau 	 = 2.6820e+03
# zmconv_dmpdz 	 = -3.8779e-04

# %%
fig,ax = plt.subplots(1,1,figsize=(12, 7)) 
ax.plot(fX, 'b.', ms=10)  # Plot all evaluated points as blue dots
ax.plot(np.minimum.accumulate(fX), 'r', lw=3)  # Plot cumulative minimum as a red line
#plt.xlim([0, len(fX)])
ax.set_ylim([0.1, 0.8])
ax.set_title("E3SM",fontsize=15)
ax.set_xlabel("Iteration",fontsize=15)
ax.set_ylabel("Skill Score",fontsize=15)

plt.tight_layout()

# %%
fig,axes = plt.subplots(3,2,figsize=(16,15))

for i in range(5):
    ind = np.arange(len(fX))
    axes[i//2][i%2].scatter(ind, X[:,i])
    axes[i//2][i%2].set_xlabel('Iteration')
    axes[i//2][i%2].set_ylabel(p_names[i])

axes[2][1].remove()
plt.tight_layout()
